# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import os
import sys
import seaborn as sns
from PIL import Image
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Pathology Data
# %store -r path_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r path_CalData

# Directory path to save Figures
# %store -r path_Fig

# %% [markdown]
# # [1] Loading

# %% [markdown]
# ## Loading Covariance Matrices (Dropped)

# %%
# covTAU_Drop
with open(os.path.join(path_CalData, 'covTAU_Drop.pkl'), 'rb') as f:
    covTAU_Drop = pickle.load(f)
f.close()

# covTDP_Drop
with open(os.path.join(path_CalData, 'covTDP_Drop.pkl'), 'rb') as f:
    covTDP_Drop = pickle.load(f)
f.close()

# covTAU_gt_TDP_Drop
with open(os.path.join(path_CalData, 'covTAU_gt_TDP_Drop.pkl'), 'rb') as f:
    covTAU_gt_TDP_Drop = pickle.load(f)
f.close()

# covTDP_gt_TAU_Drop
with open(os.path.join(path_CalData, 'covTDP_gt_TAU_Drop.pkl'), 'rb') as f:
    covTDP_gt_TAU_Drop = pickle.load(f)
f.close()

# covTAU_gt_TDP_raw_Drop
with open(os.path.join(path_CalData, 'covTAU_gt_TDP_raw_Drop.pkl'), 'rb') as f:
    covTAU_gt_TDP_raw_Drop = pickle.load(f)
f.close()

# covTDP_gt_TAU_raw_Drop
with open(os.path.join(path_CalData, 'covTDP_gt_TAU_raw_Drop.pkl'), 'rb') as f:
    covTDP_gt_TAU_raw_Drop = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Pathology Labels (TAU, TDP) - Dropped

# %%
# pathNames_TAU_Drop
with open(os.path.join(path_CalData, 'pathNames_TAU_Drop.pkl'), 'rb') as f:
    pathNames_TAU_Drop = pickle.load(f)
f.close()

# pathNames_TDP_Drop
with open(os.path.join(path_CalData, 'pathNames_TDP_Drop.pkl'), 'rb') as f:
    pathNames_TDP_Drop = pickle.load(f)
f.close()

# %% [markdown]
# # [2] Draw and Save Covariance Matrices

# %% [markdown]
# ## CovTAU

# %%
viz.drawCovMatrix(covTAU_Drop, pathNames_TAU_Drop, pathNames_TAU_Drop, 'FTD_TAU', outputDir = path_Fig,
                  annot_fontsize = 4, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## CovTDP

# %%
viz.drawCovMatrix(covTDP_Drop, pathNames_TDP_Drop, pathNames_TDP_Drop, 'FTD_TDP', outputDir = path_Fig,
                  annot_fontsize = 4, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## covTAU_gt_TDP

# %%
viz.drawCovMatrix(covTAU_gt_TDP_Drop, pathNames_TAU_Drop, pathNames_TAU_Drop, 'FTD: TAU > TDP', outputDir = path_Fig,
                  annot_fontsize = 4, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## covTDP_gt_TAU

# %%
viz.drawCovMatrix(covTDP_gt_TAU_Drop, pathNames_TDP_Drop, pathNames_TDP_Drop, 'FTD: TDP > TAU', outputDir = path_Fig,
                  annot_fontsize = 4, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrix(covTAU_gt_TDP_raw_Drop, pathNames_TAU_Drop, pathNames_TAU_Drop, 'FTD: TAU > TDP', outputDir = path_Fig,
                  annot_fontsize = 4, tick_fontsize = 6, annot_bool = True, save=True)
