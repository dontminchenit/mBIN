# %%
import os

# %% [markdown]
# # Directory Path to mBIN gitrepo

# %%
#gitRepoDir = "/Users/hyung/Research23_Network_Analysis/mBIN"
gitRepoDir = "/Users/hyroh/Desktop/FTD_Research/mBIN" # mac mini
#gitRepoDir = '/Users/hyroh/Upenn PhD/Research/mBIN' # M3
# %store gitRepoDir
# Out:
# Stored 'gitRepoDir' (str)

# %% [markdown]
# # Directory Path to Data Folder

# %%
# Location of the raw data folder
#dataDir = '/Users/hyung/Research23_Network_Analysis/NetworkAnalysisData-selected/Data'
dataDir='/Users/hyroh/Desktop/FTD_Research/Data' # mac mini
#dataDir = '/Users/hyroh/Upenn PhD/Research/Data' # M3
# %store dataDir
# Out:
# Stored 'dataDir' (str)

# %% [markdown]
# # Directory Path to Preconstructed Atlas Data

# %%
# Only used to load the FTDGeneralData_20221114.mat file --> Saved as NetworkDataGeneral
baseDir = os.path.join(gitRepoDir, 'Matlab')
# %store baseDir
# Out:
# Stored 'baseDir' (str)

# %% [markdown]
# # Directory Path to HelperFunctions

# %% [markdown]
# ## Data Loader

# %%
loadData_hf = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/HelperFunctions/Load_Dataset_HelperFunctions')
# %store loadData_hf
# Out:
# Stored 'loadData_hf' (str)

# %% [markdown]
# ## Analysis

# %%
analysis_hf = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/HelperFunctions/Analysis_HelperFuntions')
# %store analysis_hf
# Out:
# Stored 'analysis_hf' (str)

# %% [markdown]
# # Pathology

# %% [markdown]
# ## Directory Path to load formatted Pathology Data

# %%
# Directory path to load formatted Pathology Data
path_dataDir= os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Data/Pathology_Data')
# %store path_dataDir
# Out:
# Stored 'path_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Pathology Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
path_CalData = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Pathology_Analysis/Calculated_Data')
# %store path_CalData
# Out:
# Stored 'path_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness Analysis)

# %%
path_Fig = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Pathology_Analysis/Figures')
# %store path_Fig
# Out:
# Stored 'path_Fig' (str)

# %% [markdown]
# # Thickness

# %% [markdown]
# ## Directory Path to load formatted Thickness Data

# %%
# Directory path to load formatted Thickness Data
thick_dataDir= os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Data/Thickness_Data')
# %store thick_dataDir
# Out:
# Stored 'thick_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Thickness Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
thick_CalData = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Thickness_Analysis/Calculated_Data')
# %store thick_CalData
# Out:
# Stored 'thick_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness Analysis)

# %%
thick_Fig = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Thickness_Analysis/Figures')
# %store thick_Fig
# Out:
# Stored 'thick_Fig' (str)

# %% [markdown]
# # Thickness At Pathology

# %% [markdown]
# ## Directory Path to load formatted Thickness At Path Data

# %%
# Directory path to load formatted Thickness At Path Data
thickAtPath_dataDir= os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Data/ThicknessAtPath_Data')
# %store thickAtPath_dataDir
# Out:
# Stored 'thickAtPath_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Thickness At Path Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
thickAtPath_CalData = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Thickness_At_Pathology_Analysis/Calculated_Data')
# %store thickAtPath_CalData
# Out:
# Stored 'thickAtPath_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness At Path Analysis)

# %%
thickAtPath_Fig = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Thickness_At_Pathology_Analysis/Figures')
# %store thickAtPath_Fig
# Out:
# Stored 'thickAtPath_Fig' (str)

# %% [markdown]
# # GFAP, Ferritin

# %% [markdown]
# ## Directory Path to load formatted Thickness At Path Data

# %%
# Directory path to load formatted Thickness At Path Data
gfap_ferritin_dataDir= os.path.join(gitRepoDir, 'FTD_JupyterNotebook/Data/GFAP_Ferritin_Data')
# %store gfap_ferritin_dataDir
# Out:
# Stored 'gfap_ferritin_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Thickness At Path Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
gfap_ferritin_CalData = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/GFAP_Ferritin_Analysis/Calculated_Data')
# %store gfap_ferritin_CalData
# Out:
# Stored 'gfap_ferritin_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness At Path Analysis)

# %%
gfap_ferritin_Fig = os.path.join(gitRepoDir, 'FTD_JupyterNotebook/GFAP_Ferritin_Analysis/Figures')
# %store gfap_ferritin_Fig
# Out:
# Stored 'gfap_ferritin_Fig' (str)
