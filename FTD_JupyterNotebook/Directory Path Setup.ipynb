# %% [markdown]
# # Directory Path to Data Folder

# %%
# Location of the data folder
dataDir='/Users/hyung/Research23_Network_Analysis/NetworkAnalysisData-selected/Data'
# %store dataDir
# Out:
# Stored 'dataDir' (str)

# %% [markdown]
# # Directory Path to Preconstructed Atlas Data

# %%
# Only used to load the FTDGeneralData_20221114.mat file --> Saved as NetworkDataGeneral
baseDir='/Users/hyung/Research23_Network_Analysis/mBIN/Matlab'
# %store baseDir
# Out:
# Stored 'baseDir' (str)

# %% [markdown]
# # Pathology

# %% [markdown]
# ## Directory Path to load formatted Pathology Data

# %%
# Directory path to load formatted Pathology Data
path_dataDir='/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Data/Pathology_Data'
# %store path_dataDir
# Out:
# Stored 'path_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Pathology Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
path_CalData = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Pathology_Analysis/Calculated_Data'
# %store path_CalData
# Out:
# Stored 'path_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness Analysis)

# %%
path_Fig = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Pathology_Analysis/Figures'
# %store path_Fig
# Out:
# Stored 'path_Fig' (str)

# %% [markdown]
# # Thickness

# %% [markdown]
# ## Directory Path to load formatted Thickness Data

# %%
# Directory path to load formatted Thickness Data
thick_dataDir='/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Data/Thickness_Data'
# %store thick_dataDir
# Out:
# Stored 'thick_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Thickness Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
thick_CalData = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Thickness_Analysis/Calculated_Data'
# %store thick_CalData
# Out:
# Stored 'thick_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness Analysis)

# %%
thickness_Fig = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Thickness_Analysis/Figures'
# %store thickness_Fig
# Out:
# Stored 'thickness_Fig' (str)

# %% [markdown]
# # Thickness At Pathology

# %% [markdown]
# ## Directory Path to load formatted Thickness At Path Data

# %%
# Directory path to load formatted Thickness At Path Data
thickAtPath_dataDir='/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Data/ThicknessAtPath_Data'
# %store thickAtPath_dataDir
# Out:
# Stored 'thickAtPath_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Thickness At Path Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
thickAtPath_CalData = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Thickness_At_Pathology_Analysis/Calculated_Data'
# %store thickAtPath_CalData
# Out:
# Stored 'thickAtPath_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures (Thickness At Path Analysis)

# %%
thickAtPath_Fig = '/Users/hyung/Research23_Network_Analysis/FTD_JupyterNotebook/Thickness_At_Pathology_Analysis/Figures'
# %store thickAtPath_Fig
# Out:
# Stored 'thickAtPath_Fig' (str)
