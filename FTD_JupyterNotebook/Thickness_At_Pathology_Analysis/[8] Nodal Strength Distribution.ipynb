# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import nodalStrength as ns

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness At Path Data
# %store -r thickAtPath_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thickAtPath_CalData
# Directory path to save Figures
# %store -r thickAtPath_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness At Path Covariance Matrices - Dictionaries (Original, Z, W Score) / TAU, TDP --> Dropped

# %%
# cov_thickAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_dict_Drop = pickle.load(f)
f.close()

# cov_thickAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_z_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_z_dict_Drop = pickle.load(f)
f.close()

# cov_thickAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_w_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_w_dict_Drop = pickle.load(f)
f.close()

# %% [markdown]
# ## Volume At Path Covariance Matrices - Dictionaries (Original, Z, W Score) / TAU, TDP --> Dropped

# %%
# cov_volAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_volAtPath_dict_Drop.pkl'), 'rb') as f:
    cov_volAtPath_dict_Drop = pickle.load(f)
f.close()

# cov_volAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_volAtPath_z_dict_Drop.pkl'), 'rb') as f:
    cov_volAtPath_z_dict_Drop = pickle.load(f)
f.close()

# cov_volAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_volAtPath_w_dict_Drop.pkl'), 'rb') as f:
    cov_volAtPath_w_dict_Drop = pickle.load(f)
f.close()

# %% [markdown]
# # Draw Nodal Strength Distribution

# %% [markdown]
# ## Nodal Strength Distribution - Thickness At Path

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path Original

# %%
ns.nodalStrengthDist(cov_thickAtPath_dict_Drop["HC"], cov_thickAtPath_dict_Drop["TAU"], cov_thickAtPath_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_Original", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_Original).png')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path Z Score

# %%
ns.nodalStrengthDist(cov_thickAtPath_z_dict_Drop["HC"], cov_thickAtPath_z_dict_Drop["TAU"], cov_thickAtPath_z_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_ZScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_ZScore).png')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path W Score

# %%
ns.nodalStrengthDist(cov_thickAtPath_w_dict_Drop["HC"], cov_thickAtPath_w_dict_Drop["TAU"], cov_thickAtPath_w_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_WScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_WScore).png')

# %% [markdown]
# ## Nodal Strength Distribution - Volume At Path

# %% [markdown]
# ### Nodal Strength Distribution - Volume At Path Original

# %%
ns.nodalStrengthDist(cov_volAtPath_dict_Drop["HC"], cov_volAtPath_dict_Drop["TAU"], cov_volAtPath_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "VolumeAtPath_Original", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(VolumeAtPath_Original).png')

# %% [markdown]
# ### Nodal Strength Distribution - Volume At Path Z Score

# %%
ns.nodalStrengthDist(cov_volAtPath_z_dict_Drop["HC"], cov_volAtPath_z_dict_Drop["TAU"], cov_volAtPath_z_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "VolumeAtPath_ZScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(VolumeAtPath_ZScore).png')

# %% [markdown]
# ### Nodal Strength Distribution - Volume At Path W Score

# %%
ns.nodalStrengthDist(cov_volAtPath_w_dict_Drop["HC"], cov_volAtPath_w_dict_Drop["TAU"], cov_volAtPath_w_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "VolumeAtPath_WScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(VolumeAtPath_WScore).png')
