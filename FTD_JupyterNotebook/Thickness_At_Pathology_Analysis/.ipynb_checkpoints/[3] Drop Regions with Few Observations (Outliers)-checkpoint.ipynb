# %% [markdown]
# # Imports

# %%
import numpy as np
import sys
import pickle
import os

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Pathology Data
# %store -r path_dataDir
# Directory path to load Calculated Pathology Analysis Data
# %store -r path_CalData

# Directory path to load formatted Thickness At Path Data
# %store -r thickAtPath_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thickAtPath_CalData
# Directory path to save Figures
# %store -r thickAtPath_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness Values At Pathology

# %% [markdown]
# ### Thickness Values At Pathology - Original

# %%
# HCthicknessAtPath
with open(os.path.join(thickAtPath_dataDir, 'HCthicknessAtPath.pkl'), 'rb') as f:
    HCthicknessAtPath = pickle.load(f)
f.close()

# TAUthicknessAtPath
with open(os.path.join(thickAtPath_dataDir, 'TAUthicknessAtPath.pkl'), 'rb') as f:
    TAUthicknessAtPath = pickle.load(f)
f.close()

# TDPthicknessAtPath
with open(os.path.join(thickAtPath_dataDir, 'TDPthicknessAtPath.pkl'), 'rb') as f:
    TDPthicknessAtPath = pickle.load(f)
f.close()

# %% [markdown]
# ### Thickness Values At Pathology - Z Score

# %%
# HCthicknessAtPath_z
with open(os.path.join(thickAtPath_CalData, 'HCthicknessAtPath_z.pkl'), 'rb') as f:
    HCthicknessAtPath_z = pickle.load(f)
f.close()

# TAUthicknessAtPath_z
with open(os.path.join(thickAtPath_CalData, 'TAUthicknessAtPath_z.pkl'), 'rb') as f:
    TAUthicknessAtPath_z = pickle.load(f)
f.close()

# TDPthicknessAtPath_z
with open(os.path.join(thickAtPath_CalData, 'TDPthicknessAtPath_z.pkl'), 'rb') as f:
    TDPthicknessAtPath_z = pickle.load(f)
f.close()

# %% [markdown]
# ### Thickness Values At Pathology - W Score

# %%
# HCthicknessAtPath_w
with open(os.path.join(thickAtPath_CalData, 'HCthicknessAtPath_w.pkl'), 'rb') as f:
    HCthicknessAtPath_w = pickle.load(f)
f.close()

# TAUthicknessAtPath_w
with open(os.path.join(thickAtPath_CalData, 'TAUthicknessAtPath_w.pkl'), 'rb') as f:
    TAUthicknessAtPath_w = pickle.load(f)
f.close()

# TDPthicknessAtPath_w
with open(os.path.join(thickAtPath_CalData, 'TDPthicknessAtPath_w.pkl'), 'rb') as f:
    TDPthicknessAtPath_w = pickle.load(f)
f.close()

# %% [markdown]
# ### Thickness At Pathology - Covariance Matrices At Pathology

# %%
# cov_thickAtPath_dict
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_dict.pkl'), 'rb') as f:
    cov_thickAtPath_dict = pickle.load(f)
f.close()

# cov_thickAtPath_z_dict
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_z_dict.pkl'), 'rb') as f:
    cov_thickAtPath_z_dict = pickle.load(f)
f.close()

# cov_thickAtPath_w_dict
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_w_dict.pkl'), 'rb') as f:
    cov_thickAtPath_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume At Pathology

# %% [markdown]
# ### Normalized Volume At Pathology - Original

# %%
# HCnormVolumeAtPath
with open(os.path.join(thickAtPath_dataDir, 'HCnormVolumeAtPath.pkl'), 'rb') as f:
    HCnormVolumeAtPath = pickle.load(f)
f.close()

# TAUnormVolumeAtPath
with open(os.path.join(thickAtPath_dataDir, 'TAUnormVolumeAtPath.pkl'), 'rb') as f:
    TAUnormVolumeAtPath = pickle.load(f)
f.close()

# TDPnormVolumeAtPath
with open(os.path.join(thickAtPath_dataDir, 'TDPnormVolumeAtPath.pkl'), 'rb') as f:
    TDPnormVolumeAtPath = pickle.load(f)
f.close()

# %% [markdown]
# ### Normalized Volume At Pathology - Z Score

# %%
# HCnormVolAtPath_z
with open(os.path.join(thickAtPath_CalData, 'HCnormVolAtPath_z.pkl'), 'rb') as f:
    HCnormVolAtPath_z = pickle.load(f)
f.close()

# TAUnormVolAtPath_z
with open(os.path.join(thickAtPath_CalData, 'TAUnormVolAtPath_z.pkl'), 'rb') as f:
    TAUnormVolAtPath_z = pickle.load(f)
f.close()

# TDPnormVolAtPath_z
with open(os.path.join(thickAtPath_CalData, 'TDPnormVolAtPath_z.pkl'), 'rb') as f:
    TDPnormVolAtPath_z = pickle.load(f)
f.close()

# %% [markdown]
# ### Normalized Volume At Pathology - W Score

# %%
# HCnormVolAtPath_w
with open(os.path.join(thickAtPath_CalData, 'HCnormVolAtPath_w.pkl'), 'rb') as f:
    HCnormVolAtPath_w = pickle.load(f)
f.close()

# TAUnormVolAtPath_w
with open(os.path.join(thickAtPath_CalData, 'TAUnormVolAtPath_w.pkl'), 'rb') as f:
    TAUnormVolAtPath_w = pickle.load(f)
f.close()

# TDPnormVolAtPath_w
with open(os.path.join(thickAtPath_CalData, 'TDPnormVolAtPath_w.pkl'), 'rb') as f:
    TDPnormVolAtPath_w = pickle.load(f)
f.close()

# %% [markdown]
# ### Normalized Volume At Pathology - Covariance Matrices At Pathology

# %%
# cov_normVolAtPath_dict
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_dict.pkl'), 'rb') as f:
    cov_normVolAtPath_dict = pickle.load(f)
f.close()

# cov_normVolAtPath_z_dict
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_z_dict.pkl'), 'rb') as f:
    cov_normVolAtPath_z_dict = pickle.load(f)
f.close()

# cov_normVolAtPath_w_dict
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_w_dict.pkl'), 'rb') as f:
    cov_normVolAtPath_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Missing Index (=few observations) from Pathology Dataset

# %% [markdown]
# ### TAU

# %%
# TAU_missing_index
with open(os.path.join(path_CalData, 'TAU_missing_index.pkl'), 'rb') as f:
    TAU_missing_index = pickle.load(f)
f.close()

# %% [markdown]
# ### TDP

# %%
# TDP_missing_index
with open(os.path.join(path_CalData, 'TDP_missing_index.pkl'), 'rb') as f:
    TDP_missing_index = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Center of Mass of Regions (in this case it is CoM of Pathology regions)

# %%
with open(os.path.join(path_dataDir, 'pathCoM.pkl'), 'rb') as f:
    pathCoM = pickle.load(f)
f.close()

# %% [markdown]
# # Dropping the regions with few observations

# %% [markdown]
# ## Thickness At Path

# %%
TAUthicknessAtPath_Drop = np.delete(TAUthicknessAtPath, TAU_missing_index, axis = 1)
TDPthicknessAtPath_Drop = np.delete(TDPthicknessAtPath, TDP_missing_index, axis = 1)

# %% [markdown]
# ## Normalized Volume At Path

# %%
TAUnormVolumeAtPath_Drop = np.delete(TAUnormVolumeAtPath, TAU_missing_index, axis = 1)
TDPnormVolumeAtPath_Drop = np.delete(TDPnormVolumeAtPath, TDP_missing_index, axis = 1)

# %% [markdown]
# ## Z Score

# %%
TAUthicknessAtPath_z_Drop = np.delete(TAUthicknessAtPath_z, TAU_missing_index, axis = 1)
TDPthicknessAtPath_z_Drop = np.delete(TDPthicknessAtPath_z, TDP_missing_index, axis = 1)

TAUnormVolAtPath_z_Drop = np.delete(TAUnormVolAtPath_z, TAU_missing_index, axis = 1)
TDPnormVolAtPath_z_Drop = np.delete(TDPnormVolAtPath_z, TDP_missing_index, axis = 1)

# %% [markdown]
# ## W Score

# %%
TAUthicknessAtPath_w_Drop = np.delete(TAUthicknessAtPath_w, TAU_missing_index, axis = 1)
TDPthicknessAtPath_w_Drop = np.delete(TDPthicknessAtPath_w, TDP_missing_index, axis = 1)

TAUnormVolAtPath_w_Drop = np.delete(TAUnormVolAtPath_w, TAU_missing_index, axis = 1)
TDPnormVolAtPath_w_Drop = np.delete(TDPnormVolAtPath_w, TDP_missing_index, axis = 1)

# %% [markdown]
# ## Covariance Matrices

# %% [markdown]
# ### Helper Function

# %%
def covMatAtPathDrop(covDict, TAU_missing_index, TDP_missing_index):
    covDict_Drop = covDict.copy()
    
    covDict_Drop["TAU"] = np.delete(covDict_Drop["TAU"], TAU_missing_index, axis = 0)
    covDict_Drop["TDP"] = np.delete(covDict_Drop["TDP"], TDP_missing_index, axis = 0)
    covDict_Drop["TAU_gt_TDP"] = np.delete(covDict_Drop["TAU_gt_TDP"], TAU_missing_index, axis = 0)
    covDict_Drop["TDP_gt_TAU"] = np.delete(covDict_Drop["TDP_gt_TAU"], TDP_missing_index, axis = 0)
    covDict_Drop["TAU_gt_HC"] = np.delete(covDict_Drop["TAU_gt_HC"], TAU_missing_index, axis = 0)
    covDict_Drop["TAU_lt_HC"] = np.delete(covDict_Drop["TAU_lt_HC"], TAU_missing_index, axis = 0)
    covDict_Drop["TDP_gt_HC"] = np.delete(covDict_Drop["TDP_gt_HC"], TDP_missing_index, axis = 0)
    covDict_Drop["TDP_lt_HC"] = np.delete(covDict_Drop["TDP_lt_HC"], TDP_missing_index, axis = 0)
    covDict_Drop["TAU_gt_TDP_raw"] = np.delete(covDict_Drop["TAU_gt_TDP_raw"], TAU_missing_index, axis = 0)
    covDict_Drop["TDP_gt_TAU_raw"] = np.delete(covDict_Drop["TDP_gt_TAU_raw"], TDP_missing_index, axis = 0)
    covDict_Drop["TAU_gt_HC_raw"] = np.delete(covDict_Drop["TAU_gt_HC_raw"], TAU_missing_index, axis = 0)
    covDict_Drop["TAU_lt_HC_raw"] = np.delete(covDict_Drop["TAU_lt_HC_raw"], TAU_missing_index, axis = 0)
    covDict_Drop["TDP_gt_HC_raw"] = np.delete(covDict_Drop["TDP_gt_HC_raw"], TDP_missing_index, axis = 0)
    covDict_Drop["TDP_lt_HC_raw"] = np.delete(covDict_Drop["TDP_lt_HC_raw"], TDP_missing_index, axis = 0)
    
    covDict_Drop["TAU"] = np.delete(covDict_Drop["TAU"], TAU_missing_index, axis = 1)
    covDict_Drop["TDP"] = np.delete(covDict_Drop["TDP"], TDP_missing_index, axis = 1)
    covDict_Drop["TAU_gt_TDP"] = np.delete(covDict_Drop["TAU_gt_TDP"], TAU_missing_index, axis = 1)
    covDict_Drop["TDP_gt_TAU"] = np.delete(covDict_Drop["TDP_gt_TAU"], TDP_missing_index, axis = 1)
    covDict_Drop["TAU_gt_HC"] = np.delete(covDict_Drop["TAU_gt_HC"], TAU_missing_index, axis = 1)
    covDict_Drop["TAU_lt_HC"] = np.delete(covDict_Drop["TAU_lt_HC"], TAU_missing_index, axis = 1)
    covDict_Drop["TDP_gt_HC"] = np.delete(covDict_Drop["TDP_gt_HC"], TDP_missing_index, axis = 1)
    covDict_Drop["TDP_lt_HC"] = np.delete(covDict_Drop["TDP_lt_HC"], TDP_missing_index, axis = 1)
    covDict_Drop["TAU_gt_TDP_raw"] = np.delete(covDict_Drop["TAU_gt_TDP_raw"], TAU_missing_index, axis = 1)
    covDict_Drop["TDP_gt_TAU_raw"] = np.delete(covDict_Drop["TDP_gt_TAU_raw"], TDP_missing_index, axis = 1)
    covDict_Drop["TAU_gt_HC_raw"] = np.delete(covDict_Drop["TAU_gt_HC_raw"], TAU_missing_index, axis = 1)
    covDict_Drop["TAU_lt_HC_raw"] = np.delete(covDict_Drop["TAU_lt_HC_raw"], TAU_missing_index, axis = 1)
    covDict_Drop["TDP_gt_HC_raw"] = np.delete(covDict_Drop["TDP_gt_HC_raw"], TDP_missing_index, axis = 1)
    covDict_Drop["TDP_lt_HC_raw"] = np.delete(covDict_Drop["TDP_lt_HC_raw"], TDP_missing_index, axis = 1)
    
    return covDict_Drop

# %%
cov_thickAtPath_dict_Drop = covMatAtPathDrop(cov_thickAtPath_dict, TAU_missing_index, TDP_missing_index)
cov_thickAtPath_z_dict_Drop = covMatAtPathDrop(cov_thickAtPath_z_dict, TAU_missing_index, TDP_missing_index)
cov_thickAtPath_w_dict_Drop = covMatAtPathDrop(cov_thickAtPath_w_dict, TAU_missing_index, TDP_missing_index)

# %%
cov_normVolAtPath_dict_Drop = covMatAtPathDrop(cov_normVolAtPath_dict, TAU_missing_index, TDP_missing_index)
cov_normVolAtPath_z_dict_Drop = covMatAtPathDrop(cov_normVolAtPath_z_dict, TAU_missing_index, TDP_missing_index)
cov_normVolAtPath_w_dict_Drop = covMatAtPathDrop(cov_normVolAtPath_w_dict, TAU_missing_index, TDP_missing_index)

# %% [markdown]
# # Saving

# %% [markdown]
# ## Dropped Thickness At Path & Normalized Volume At Path

# %%
# TAUthicknessAtPath_Drop
with open(os.path.join(thickAtPath_dataDir, 'TAUthicknessAtPath_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUthicknessAtPath_Drop, f)
f.close()

# TDPthicknessAtPath_Drop
with open(os.path.join(thickAtPath_dataDir, 'TDPthicknessAtPath_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPthicknessAtPath_Drop, f)
f.close()

# TAUnormVolumeAtPath_Drop
with open(os.path.join(thickAtPath_dataDir, 'TAUnormVolumeAtPath_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUnormVolumeAtPath_Drop, f)
f.close()

# TDPnormVolumeAtPath_Drop
with open(os.path.join(thickAtPath_dataDir, 'TDPnormVolumeAtPath_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPnormVolumeAtPath_Drop, f)
f.close()

# %% [markdown]
# ## Z Score

# %%
# TAUthicknessAtPath_z_Drop
with open(os.path.join(thickAtPath_CalData, 'TAUthicknessAtPath_z_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUthicknessAtPath_z_Drop, f)
f.close()

# TDPthicknessAtPath_z_Drop
with open(os.path.join(thickAtPath_CalData, 'TDPthicknessAtPath_z_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPthicknessAtPath_z_Drop, f)
f.close()

# TAUnormVolAtPath_z_Drop
with open(os.path.join(thickAtPath_CalData, 'TAUnormVolAtPath_z_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUnormVolAtPath_z_Drop, f)
f.close()

# TDPnormVolAtPath_z_Drop
with open(os.path.join(thickAtPath_CalData, 'TDPnormVolAtPath_z_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPnormVolAtPath_z_Drop, f)
f.close()

# %% [markdown]
# ## W Score

# %%
# TAUthicknessAtPath_w_Drop
with open(os.path.join(thickAtPath_CalData, 'TAUthicknessAtPath_w_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUthicknessAtPath_w_Drop, f)
f.close()

# TDPthicknessAtPath_w_Drop
with open(os.path.join(thickAtPath_CalData, 'TDPthicknessAtPath_w_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPthicknessAtPath_w_Drop, f)
f.close()

# TAUnormVolAtPath_w_Drop
with open(os.path.join(thickAtPath_CalData, 'TAUnormVolAtPath_w_Drop.pkl'), 'wb') as f:
    pickle.dump(TAUnormVolAtPath_w_Drop, f)
f.close()

# TDPnormVolAtPath_w_Drop
with open(os.path.join(thickAtPath_CalData, 'TDPnormVolAtPath_w_Drop.pkl'), 'wb') as f:
    pickle.dump(TDPnormVolAtPath_w_Drop, f)
f.close()

# %% [markdown]
# ## Covariance Matrices

# %%
# cov_thickAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_thickAtPath_dict_Drop, f)
f.close()

# cov_thickAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_z_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_thickAtPath_z_dict_Drop, f)
f.close()

# cov_thickAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_w_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_thickAtPath_w_dict_Drop, f)
f.close()

#-----

# cov_normVolAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_normVolAtPath_dict_Drop, f)
f.close()

# cov_normVolAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_z_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_normVolAtPath_z_dict_Drop, f)
f.close()

# cov_normVolAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_w_dict_Drop.pkl'), 'wb') as f:
    pickle.dump(cov_normVolAtPath_w_dict_Drop, f)
f.close()
