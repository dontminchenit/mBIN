# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import nodalStrength as ns

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness At Path Data
# %store -r thickAtPath_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thickAtPath_CalData
# Directory path to save Figures
# %store -r thickAtPath_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness At Path Covariance Matrices - Dictionaries (Original, Z, W Score) / TAU, TDP --> Dropped

# %%
# cov_thickAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_dict_Drop = pickle.load(f)
f.close()

# cov_thickAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_z_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_z_dict_Drop = pickle.load(f)
f.close()

# cov_thickAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_thickAtPath_w_dict_Drop.pkl'), 'rb') as f:
    cov_thickAtPath_w_dict_Drop = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume At Path Covariance Matrices - Dictionaries (Original, Z, W Score) / TAU, TDP --> Dropped

# %%
# cov_normVolAtPath_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_dict_Drop.pkl'), 'rb') as f:
    cov_normVolAtPath_dict_Drop = pickle.load(f)
f.close()

# cov_normVolAtPath_z_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_z_dict_Drop.pkl'), 'rb') as f:
    cov_normVolAtPath_z_dict_Drop = pickle.load(f)
f.close()

# cov_normVolAtPath_w_dict_Drop
with open(os.path.join(thickAtPath_CalData, 'cov_normVolAtPath_w_dict_Drop.pkl'), 'rb') as f:
    cov_normVolAtPath_w_dict_Drop = pickle.load(f)
f.close()

# %% [markdown]
# # Draw Nodal Strength Distribution

# %% [markdown]
# ## Nodal Strength Distribution - Thickness At Path

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path Original

# %%
ns.nodalStrengthDist(cov_thickAtPath_dict_Drop["HC"], cov_thickAtPath_dict_Drop["TAU"], cov_thickAtPath_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_Original", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_Original)')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path Z Score

# %%
ns.nodalStrengthDist(cov_thickAtPath_z_dict_Drop["HC"], cov_thickAtPath_z_dict_Drop["TAU"], cov_thickAtPath_z_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_ZScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_ZScore)')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness At Path W Score

# %%
ns.nodalStrengthDist(cov_thickAtPath_w_dict_Drop["HC"], cov_thickAtPath_w_dict_Drop["TAU"], cov_thickAtPath_w_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "ThicknessAtPath_WScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(ThicknessAtPath_WScore)')

# %% [markdown]
# ## Nodal Strength Distribution - Normalized Volume At Path

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume At Path Original

# %%
ns.nodalStrengthDist(cov_normVolAtPath_dict_Drop["HC"], cov_normVolAtPath_dict_Drop["TAU"], cov_normVolAtPath_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolumeAtPath_Original", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolumeAtPath_Original)')

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume At Path Z Score

# %%
ns.nodalStrengthDist(cov_normVolAtPath_z_dict_Drop["HC"], cov_normVolAtPath_z_dict_Drop["TAU"], cov_normVolAtPath_z_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolumeAtPath_ZScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolumeAtPath_ZScore)')

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume At Path W Score

# %%
ns.nodalStrengthDist(cov_normVolAtPath_w_dict_Drop["HC"], cov_normVolAtPath_w_dict_Drop["TAU"], cov_normVolAtPath_w_dict_Drop["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolumeAtPath_WScore", 
                     thickAtPath_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolumeAtPath_WScore)')
