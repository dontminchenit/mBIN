# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle
import scipy

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import atlasMapping
import fixedDensity as fd

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load preconstructed Atlas Data
# %store -r baseDir
# Directory path to load formatted Thickness Data
# %store -r thick_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thick_CalData
# Directory path to save Figures
# %store -r thick_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading the preconstructed atlas data

# %%
# loads the preconstructed Atlas data
NetworkDataGeneral = scipy.io.loadmat(os.path.join(baseDir, 'NetworkAnalysisGeneral', 'FTDGeneralData_20221114.mat'))

# %% [markdown]
# ## Thickness Data (from selected network), HC, TAU, and TDP

# %%
# thickHC
with open(os.path.join(thick_CalData, 'thickHC.pkl'), 'rb') as f:
    thickHC = pickle.load(f)
f.close()

# thickTAU
with open(os.path.join(thick_CalData, 'thickTAU.pkl'), 'rb') as f:
    thickTAU = pickle.load(f)
f.close()

# thickTDP
with open(os.path.join(thick_CalData, 'thickTDP.pkl'), 'rb') as f:
    thickTDP = pickle.load(f)
f.close()

# %% [markdown]
# ## W Score of Normalized Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_normvol_w
with open(os.path.join(thick_CalData, 'HC_normvol_w.pkl'), 'rb') as f:
    HC_normvol_w = pickle.load(f)
f.close()

# TAU_normvol_w
with open(os.path.join(thick_CalData, 'TAU_normvol_w.pkl'), 'rb') as f:
    TAU_normvol_w = pickle.load(f)
f.close()

# TDP_normvol_w
with open(os.path.join(thick_CalData, 'TDP_normvol_w.pkl'), 'rb') as f:
    TDP_normvol_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Thickness Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_thick_dict
with open(os.path.join(thick_CalData, 'cov_thick_dict.pkl'), 'rb') as f:
    cov_thick_dict = pickle.load(f)
f.close()

# cov_thick_z_dict
with open(os.path.join(thick_CalData, 'cov_thick_z_dict.pkl'), 'rb') as f:
    cov_thick_z_dict = pickle.load(f)
f.close()

# cov_thick_w_dict
with open(os.path.join(thick_CalData, 'cov_thick_w_dict.pkl'), 'rb') as f:
    cov_thick_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_normVol_dict
with open(os.path.join(thick_CalData, 'cov_normVol_dict.pkl'), 'rb') as f:
    cov_normVol_dict = pickle.load(f)
f.close()

# cov_normVol_z_dict
with open(os.path.join(thick_CalData, 'cov_normVol_z_dict.pkl'), 'rb') as f:
    cov_normVol_z_dict = pickle.load(f)
f.close()

# cov_normVol_w_dict
with open(os.path.join(thick_CalData, 'cov_normVol_w_dict.pkl'), 'rb') as f:
    cov_normVol_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Center of Mass for the Selected Network

# %%
# currCoM
with open(os.path.join(thick_CalData, 'currCoM.pkl'), 'rb') as f:
    currCoM = pickle.load(f)
f.close()

# %% [markdown]
# ## Atlas Region Names

# %%
# regNames
with open(os.path.join(thick_CalData, 'regNames.pkl'), 'rb') as f:
    regNames = pickle.load(f)
f.close()

# %% [markdown]
# # Draw 3D Atlas Map

# %% [markdown]
# ## Define Variables

# %% [markdown]
# ### Set fixed density value

# %%
fd_val = 40 # Get top 100

# %% [markdown]
# ## Thickness Value - Original

# %% [markdown]
# ### Define Vectors for Node Size and Node Color

# %%
# FOR NODE SIZE (Original Thickness Value)
thick_HC_exp = thickHC
thick_TAU_exp = thickTAU
thick_TDP_exp = thickTDP

# Get the MAX/MIN Thickness values
minThick_HC = np.nanmin(np.nanmean(thick_HC_exp, axis=0))
minThick_TAU = np.nanmin(np.nanmean(thick_TAU_exp, axis=0))
minThick_TDP = np.nanmin(np.nanmean(thick_TDP_exp, axis=0))

vanishing_val = 0.2
maxThick_HC = np.nanmax(np.nanmean(thick_HC_exp, axis=0) - minThick_HC) + vanishing_val
maxThick_TAU = np.nanmax(np.nanmean(thick_TAU_exp, axis=0) - minThick_TAU) + vanishing_val
maxThick_TDP = np.nanmax(np.nanmean(thick_TDP_exp, axis=0) - minThick_TDP) + vanishing_val

# NODE Size
markerVecHC = np.nanmean(thick_HC_exp, axis=0)
markerVecHC = 3 * (1 - ((markerVecHC - minThick_HC) / maxThick_HC))

markerVecTAU = np.nanmean(thick_TAU_exp, axis=0)
markerVecTAU = 3 * (1 - ((markerVecTAU - minThick_TAU) / maxThick_TAU))

markerVecTDP = np.nanmean(thick_TDP_exp, axis=0)
markerVecTDP = 3 * (1 - ((markerVecTDP - minThick_TDP) / maxThick_TDP))

# Set Node color --> Set as red (because cm.jet: 1 --> Red) Same for all HC/TAU/TDP
colorVec = np.ones(thickHC.shape[1])

# %% [markdown]
# ### HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['HC'], currCoM, regNames, markerVecHC, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_HC', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TAU'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_TAU', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TDP'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_TDP', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TAU_gt_HC'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_gt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TDP_gt_HC'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_gt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TAU_lt_HC'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_lt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TDP_lt_HC'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_lt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TAU_gt_TDP'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_gt_TDP)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_thick_dict['TDP_gt_TAU'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_gt_TAU)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ## Thickness Value - Original - Fixed Density

# %% [markdown]
# ### HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['HC'], fd_val), currCoM, regNames, 
                          markerVecHC, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_HC(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TAU'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_TAU(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TDP'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_TDP(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TAU_gt_HC_raw'], fd_val), currCoM, regNames,
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_gt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TDP_gt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_gt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TAU_lt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_lt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TDP_lt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_lt_HC)(FixedDensity_40)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TAU_gt_TDP_raw'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TAU_gt_TDP)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_thick_dict['TDP_gt_TAU_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_(TDP_gt_TAU)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ## Normalized Volume - W Score

# %% [markdown]
# ### Define Vectors for Node Size and Node Color

# %%
# FOR NODE SIZE (Original Thickness Value)
HC_normvol_w_exp = HC_normvol_w
TAU_normvol_exp = TAU_normvol_w
TDP_normvol_exp = TDP_normvol_w

# Get the MAX/MIN Thickness values
minNormVol_HC = np.nanmin(np.nanmean(HC_normvol_w_exp, axis=0))
minNormVol_TAU = np.nanmin(np.nanmean(TAU_normvol_exp, axis=0))
minNormVol_TDP = np.nanmin(np.nanmean(TDP_normvol_exp, axis=0))

vanishing_val = 0.2
maxNormVol_HC = np.nanmax(np.nanmean(HC_normvol_w_exp, axis=0) - minNormVol_HC) + vanishing_val
maxNormVol_TAU = np.nanmax(np.nanmean(TAU_normvol_exp, axis=0) - minNormVol_TAU) + vanishing_val
maxNormVol_TDP = np.nanmax(np.nanmean(TDP_normvol_exp, axis=0) - minNormVol_TDP) + vanishing_val


markerVecHC = np.nanmean(HC_normvol_w_exp, axis=0)
markerVecHC = 3 * (1 - ((markerVecHC - minNormVol_HC) / maxNormVol_HC))

markerVecTAU = np.nanmean(TAU_normvol_exp, axis=0)
markerVecTAU = 3 * (1 - ((markerVecTAU - minNormVol_TAU) / maxNormVol_TAU))

markerVecTDP = np.nanmean(TDP_normvol_exp, axis=0)
markerVecTDP = 3 * (1 - ((markerVecTDP - minNormVol_TDP) / maxNormVol_TDP))

# %% [markdown]
# ### HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['HC'], currCoM, regNames, markerVecHC, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_HC', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TAU'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_TAU', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TDP'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_TDP', covType='original', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TAU_gt_HC'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_gt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TDP_gt_HC'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_gt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TAU_lt_HC'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_lt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TDP_lt_HC'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_lt_HC)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TAU_gt_TDP'], currCoM, regNames, markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_gt_TDP)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, cov_normVol_w_dict['TDP_gt_TAU'], currCoM, regNames, markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_gt_TAU)', covType='sig', nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ## Normalized Volume - W Score - Fixed Density

# %% [markdown]
# ### HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['HC'], fd_val), currCoM, regNames, 
                          markerVecHC, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_HC(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TAU'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_TAU(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TDP'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_TDP(FixedDensity_40)', covType='original', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TAU_gt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_gt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TDP_gt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_gt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TAU_lt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_lt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP < HC

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TDP_lt_HC_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_lt_HC)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TAU > TDP

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TAU_gt_TDP_raw'], fd_val), currCoM, regNames, 
                          markerVecTAU, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TAU_gt_TDP)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)

# %% [markdown]
# ### TDP > TAU

# %%
atlasMapping.atlasMapping(NetworkDataGeneral, fd.fixedDensity(cov_normVol_w_dict['TDP_gt_TAU_raw'], fd_val), currCoM, regNames, 
                          markerVecTDP, colorVec, 
                          thick_Fig, '3D_Atlas_CovMat_normVol_w_(TDP_gt_TAU)(FixedDensity_40)', covType='sig', 
                          nodeTransparency = 0.3, 
                          edgeTransparency = 0.8, atlasTransparency = 0.01, showLabels = 0, surfDisp=None)
