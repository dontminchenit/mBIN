# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import nodalStrength as ns

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness Data
# %store -r thick_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thick_CalData
# Directory path to save Figures
# %store -r thick_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_thick_dict
with open(os.path.join(thick_CalData, 'cov_thick_dict.pkl'), 'rb') as f:
    cov_thick_dict = pickle.load(f)
f.close()

# cov_thick_z_dict
with open(os.path.join(thick_CalData, 'cov_thick_z_dict.pkl'), 'rb') as f:
    cov_thick_z_dict = pickle.load(f)
f.close()

# cov_thick_w_dict
with open(os.path.join(thick_CalData, 'cov_thick_w_dict.pkl'), 'rb') as f:
    cov_thick_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_normVol_dict
with open(os.path.join(thick_CalData, 'cov_normVol_dict.pkl'), 'rb') as f:
    cov_normVol_dict = pickle.load(f)
f.close()

# cov_normVol_z_dict
with open(os.path.join(thick_CalData, 'cov_normVol_z_dict.pkl'), 'rb') as f:
    cov_normVol_z_dict = pickle.load(f)
f.close()

# cov_normVol_w_dict
with open(os.path.join(thick_CalData, 'cov_normVol_w_dict.pkl'), 'rb') as f:
    cov_normVol_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# # Draw Nodal Strength Distribution

# %% [markdown]
# ## Nodal Strength Distribution - Thickness

# %% [markdown]
# ### Nodal Strength Distribution - Thickness Original

# %%
ns.nodalStrengthDist(cov_thick_dict["HC"], cov_thick_dict["TAU"], cov_thick_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "Thickness_Original", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(Thickness_Original)')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness Z Score

# %%
ns.nodalStrengthDist(cov_thick_z_dict["HC"], cov_thick_z_dict["TAU"], cov_thick_z_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "Thickness_ZScore", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(Thickness_ZScore)')

# %% [markdown]
# ### Nodal Strength Distribution - Thickness W Score

# %%
ns.nodalStrengthDist(cov_thick_w_dict["HC"], cov_thick_w_dict["TAU"], cov_thick_w_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "Thickness_WScore", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(Thickness_WScore)')

# %% [markdown]
# ## Nodal Strength Distribution - Normalized Volume

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume Original

# %%
ns.nodalStrengthDist(cov_normVol_dict["HC"], cov_normVol_dict["TAU"], cov_normVol_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolume_Original", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolume_Original)')

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume Z Score

# %%
ns.nodalStrengthDist(cov_normVol_z_dict["HC"], cov_normVol_z_dict["TAU"], cov_normVol_z_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolume_ZScore", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolume_ZScore)')

# %% [markdown]
# ### Nodal Strength Distribution - Normalized Volume W Score

# %%
ns.nodalStrengthDist(cov_normVol_w_dict["HC"], cov_normVol_w_dict["TAU"], cov_normVol_w_dict["TDP"], 
                     ['HC', 'TAU', 'TDP'], 'Nodal Strength', "NormalizedVolume_WScore", 
                     thick_Fig, 'FTD_NodalStrenght_Dist(NormalizedVolume_WScore)')
