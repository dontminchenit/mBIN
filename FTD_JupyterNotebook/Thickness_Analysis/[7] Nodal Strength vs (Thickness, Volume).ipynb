# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import nodalStrength as ns

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness Data
# %store -r thick_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thick_CalData
# Directory path to save Figures
# %store -r thick_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness Data

# %% [markdown]
# ### Thickness Data (from selected network), HC, TAU, and TDP

# %%
# thickHC
with open(os.path.join(thick_CalData, 'thickHC.pkl'), 'rb') as f:
    thickHC = pickle.load(f)
f.close()

# thickTAU
with open(os.path.join(thick_CalData, 'thickTAU.pkl'), 'rb') as f:
    thickTAU = pickle.load(f)
f.close()

# thickTDP
with open(os.path.join(thick_CalData, 'thickTDP.pkl'), 'rb') as f:
    thickTDP = pickle.load(f)
f.close()

# %% [markdown]
# ### Z Score of Thickness Data (from selected network), HC, TAU, and TDP

# %%
# HC_z
with open(os.path.join(thick_CalData, 'HC_z.pkl'), 'rb') as f:
    HC_z = pickle.load(f)
f.close()

# TAU_z
with open(os.path.join(thick_CalData, 'TAU_z.pkl'), 'rb') as f:
    TAU_z = pickle.load(f)
f.close()

# TDP_z
with open(os.path.join(thick_CalData, 'TDP_z.pkl'), 'rb') as f:
    TDP_z = pickle.load(f)
f.close()

# %% [markdown]
# ### W Score of Thickness Data (from selected network), HC, TAU, and TDP

# %%
# HC_w
with open(os.path.join(thick_CalData, 'HC_w.pkl'), 'rb') as f:
    HC_w = pickle.load(f)
f.close()

# TAU_w
with open(os.path.join(thick_CalData, 'TAU_w.pkl'), 'rb') as f:
    TAU_w = pickle.load(f)
f.close()

# TDP_w
with open(os.path.join(thick_CalData, 'TDP_w.pkl'), 'rb') as f:
    TDP_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Volume Data

# %% [markdown]
# ### Volume Data (from selected network), HC, TAU, and TDP

# %%
# volHC
with open(os.path.join(thick_CalData, 'volHC.pkl'), 'rb') as f:
    volHC = pickle.load(f)
f.close()

# volTAU
with open(os.path.join(thick_CalData, 'volTAU.pkl'), 'rb') as f:
    volTAU = pickle.load(f)
f.close()

# volTDP
with open(os.path.join(thick_CalData, 'volTDP.pkl'), 'rb') as f:
    volTDP = pickle.load(f)
f.close()

# %% [markdown]
# ### Z Score of Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_vol_z
with open(os.path.join(thick_CalData, 'HC_vol_z.pkl'), 'rb') as f:
    HC_vol_z = pickle.load(f)
f.close()

# TAU_vol_z
with open(os.path.join(thick_CalData, 'TAU_vol_z.pkl'), 'rb') as f:
    TAU_vol_z = pickle.load(f)
f.close()

# TDP_vol_z
with open(os.path.join(thick_CalData, 'TDP_vol_z.pkl'), 'rb') as f:
    TDP_vol_z = pickle.load(f)
f.close()

# %% [markdown]
# ### W Score of Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_vol_w
with open(os.path.join(thick_CalData, 'HC_vol_w.pkl'), 'rb') as f:
    HC_vol_w = pickle.load(f)
f.close()

# TAU_vol_w
with open(os.path.join(thick_CalData, 'TAU_vol_w.pkl'), 'rb') as f:
    TAU_vol_w = pickle.load(f)
f.close()

# TDP_vol_w
with open(os.path.join(thick_CalData, 'TDP_vol_w.pkl'), 'rb') as f:
    TDP_vol_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Thickness Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_thick_dict
with open(os.path.join(thick_CalData, 'cov_thick_dict.pkl'), 'rb') as f:
    cov_thick_dict = pickle.load(f)
f.close()

# cov_thick_z_dict
with open(os.path.join(thick_CalData, 'cov_thick_z_dict.pkl'), 'rb') as f:
    cov_thick_z_dict = pickle.load(f)
f.close()

# cov_thick_w_dict
with open(os.path.join(thick_CalData, 'cov_thick_w_dict.pkl'), 'rb') as f:
    cov_thick_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Volume Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_vol_dict
with open(os.path.join(thick_CalData, 'cov_vol_dict.pkl'), 'rb') as f:
    cov_vol_dict = pickle.load(f)
f.close()

# cov_vol_z_dict
with open(os.path.join(thick_CalData, 'cov_vol_z_dict.pkl'), 'rb') as f:
    cov_vol_z_dict = pickle.load(f)
f.close()

# cov_vol_w_dict
with open(os.path.join(thick_CalData, 'cov_vol_w_dict.pkl'), 'rb') as f:
    cov_vol_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# # Draw Nodal Strength vs Thickness Values

# %% [markdown]
# ## Thickness Data - Original

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(thickHC, cov_thick_dict["HC"], 'FTD_Thickness_HC', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(thickTAU, cov_thick_dict["TAU"], 'FTD_Thickness_TAU', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(thickTDP, cov_thick_dict["TDP"], 'FTD_Thickness_TDP', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Thickness Data - Z Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_z, cov_thick_z_dict["HC"], 'FTD_Thickness_HC_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_z, cov_thick_z_dict["TAU"], 'FTD_Thickness_TAU_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_z, cov_thick_z_dict["TDP"], 'FTD_Thickness_TDP_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Thickness Data - W Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_w, cov_thick_w_dict["HC"], 'FTD_Thickness_HC_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_w, cov_thick_w_dict["TAU"], 'FTD_Thickness_TAU_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_w, cov_thick_w_dict["TDP"], 'FTD_Thickness_TDP_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# # Draw Nodal Strength vs Volume Values

# %% [markdown]
# ## Volume Data - Original

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(volHC, cov_vol_dict["HC"], 'FTD_Vol_HC', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_Orig_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(volTAU, cov_vol_dict["TAU"], 'FTD_Vol_TAU', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_Orig_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(volTDP, cov_vol_dict["TDP"], 'FTD_Vol_TDP', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_Orig_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Volume Data - Z Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_vol_z, cov_vol_z_dict["HC"], 'FTD_Vol_HC_ZScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_ZScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_vol_z, cov_vol_z_dict["TAU"], 'FTD_Vol_TAU_ZScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_ZScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_vol_z, cov_vol_z_dict["TDP"], 'FTD_Vol_TDP_ZScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_ZScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Volume Data - W Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_vol_w, cov_vol_w_dict["HC"], 'FTD_Vol_HC_WScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_WScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_vol_w, cov_vol_w_dict["TAU"], 'FTD_Vol_TAU_WScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_WScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_vol_w, cov_vol_w_dict["TDP"], 'FTD_Vol_TDP_WScore', 'Degree', 'Mean Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Vol_WScore_(TDP)', 
                  linear_regression = True)
