# %% [markdown]
# # Imports

# %%
import numpy as np
import sys
import os
import pickle

# %% [markdown]
# ### Helper Fuctions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import boxPlot as bp

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness Data
# %store -r thick_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thick_CalData
# Directory path to save the Generated Figures
# %store -r thickness_Fig

# %% [markdown]
# # [1] Loading

# %% [markdown]
# ## Volume Data (from selected network), HC, TAU, and TDP

# %%
# volHC
with open(os.path.join(thick_CalData, 'volHC.pkl'), 'rb') as f:
    volHC = pickle.load(f)
f.close()

# volTAU
with open(os.path.join(thick_CalData, 'volTAU.pkl'), 'rb') as f:
    volTAU = pickle.load(f)
f.close()

# volTDP
with open(os.path.join(thick_CalData, 'volTDP.pkl'), 'rb') as f:
    volTDP = pickle.load(f)
f.close()

# %% [markdown]
# ## Z Score of Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_vol_z
with open(os.path.join(thick_CalData, 'HC_vol_z.pkl'), 'rb') as f:
    HC_vol_z = pickle.load(f)
f.close()

# TAU_vol_z
with open(os.path.join(thick_CalData, 'TAU_vol_z.pkl'), 'rb') as f:
    TAU_vol_z = pickle.load(f)
f.close()

# TDP_vol_z
with open(os.path.join(thick_CalData, 'TDP_vol_z.pkl'), 'rb') as f:
    TDP_vol_z = pickle.load(f)
f.close()

# %% [markdown]
# ## W Score of Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_vol_w
with open(os.path.join(thick_CalData, 'HC_vol_w.pkl'), 'rb') as f:
    HC_vol_w = pickle.load(f)
f.close()

# TAU_vol_w
with open(os.path.join(thick_CalData, 'TAU_vol_w.pkl'), 'rb') as f:
    TAU_vol_w = pickle.load(f)
f.close()

# TDP_vol_w
with open(os.path.join(thick_CalData, 'TDP_vol_w.pkl'), 'rb') as f:
    TDP_vol_w = pickle.load(f)
f.close()

# %% [markdown]
# # Generate Box plot of  Volume/Z-Score/W-Score Distributions (Mean across subjects)

# %% [markdown]
# ## Distribution of Normalized Volume

# %%
bp.drawthicknessboxplot(volHC, volTAU, volTDP, ['HC', 'TAU', 'TDP'], 
                     'Mean Volume', "Volume Original Value Distribution", thickness_Fig, 
                        "FTD_Distribution_Volume_Original.png")

# %% [markdown]
# ## Distribution of Normalized Volume Z-Score

# %%
bp.drawthicknessboxplot(HC_vol_z, TAU_vol_z, TDP_vol_z, ['HC', 'TAU', 'TDP'], 
                     'Mean Volume Z-Score', "Volume Z-Score Distribution", thickness_Fig, 
                        "FTD_Distribution_Volume_ZScore.png")

# %% [markdown]
# ## Distribution of Normalized Volume W-Score

# %%
bp.drawthicknessboxplot(HC_vol_w, TAU_vol_w, TDP_vol_w, ['HC', 'TAU', 'TDP'], 
                     'Mean Volume W-Score', "Volume W-Score Distribution", thickness_Fig, 
                        "FTD_Distribution_Volume_WScore.png")
