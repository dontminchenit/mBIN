# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import sys
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import nodalStrength as ns

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Thickness Data
# %store -r thick_dataDir
# Directory path to save Calcualted Analysis Data
# %store -r thick_CalData
# Directory path to save Figures
# %store -r thick_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Thickness Data

# %% [markdown]
# ### Thickness Data (from selected network), HC, TAU, and TDP

# %%
# thickHC
with open(os.path.join(thick_CalData, 'thickHC.pkl'), 'rb') as f:
    thickHC = pickle.load(f)
f.close()

# thickTAU
with open(os.path.join(thick_CalData, 'thickTAU.pkl'), 'rb') as f:
    thickTAU = pickle.load(f)
f.close()

# thickTDP
with open(os.path.join(thick_CalData, 'thickTDP.pkl'), 'rb') as f:
    thickTDP = pickle.load(f)
f.close()

# %% [markdown]
# ### Z Score of Thickness Data (from selected network), HC, TAU, and TDP

# %%
# HC_z
with open(os.path.join(thick_CalData, 'HC_z.pkl'), 'rb') as f:
    HC_z = pickle.load(f)
f.close()

# TAU_z
with open(os.path.join(thick_CalData, 'TAU_z.pkl'), 'rb') as f:
    TAU_z = pickle.load(f)
f.close()

# TDP_z
with open(os.path.join(thick_CalData, 'TDP_z.pkl'), 'rb') as f:
    TDP_z = pickle.load(f)
f.close()

# %% [markdown]
# ### W Score of Thickness Data (from selected network), HC, TAU, and TDP

# %%
# HC_w
with open(os.path.join(thick_CalData, 'HC_w.pkl'), 'rb') as f:
    HC_w = pickle.load(f)
f.close()

# TAU_w
with open(os.path.join(thick_CalData, 'TAU_w.pkl'), 'rb') as f:
    TAU_w = pickle.load(f)
f.close()

# TDP_w
with open(os.path.join(thick_CalData, 'TDP_w.pkl'), 'rb') as f:
    TDP_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume Data

# %% [markdown]
# ### Normalized Volume Data (from selected network), HC, TAU, and TDP

# %%
# normVolumeHC
with open(os.path.join(thick_CalData, 'normVolumeHC.pkl'), 'rb') as f:
    normVolumeHC = pickle.load(f)
f.close()

# normVolumeTAU
with open(os.path.join(thick_CalData, 'normVolumeTAU.pkl'), 'rb') as f:
    normVolumeTAU = pickle.load(f)
f.close()

# normVolumeTDP
with open(os.path.join(thick_CalData, 'normVolumeTDP.pkl'), 'rb') as f:
    normVolumeTDP = pickle.load(f)
f.close()

# %% [markdown]
# ### Z Score of Normalized Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_normvol_z
with open(os.path.join(thick_CalData, 'HC_normvol_z.pkl'), 'rb') as f:
    HC_normvol_z = pickle.load(f)
f.close()

# TAU_normvol_z
with open(os.path.join(thick_CalData, 'TAU_normvol_z.pkl'), 'rb') as f:
    TAU_normvol_z = pickle.load(f)
f.close()

# TDP_normvol_z
with open(os.path.join(thick_CalData, 'TDP_normvol_z.pkl'), 'rb') as f:
    TDP_normvol_z = pickle.load(f)
f.close()

# %% [markdown]
# ### W Score of Normalized Volume Data (from selected network), HC, TAU, and TDP

# %%
# HC_normvol_w
with open(os.path.join(thick_CalData, 'HC_normvol_w.pkl'), 'rb') as f:
    HC_normvol_w = pickle.load(f)
f.close()

# TAU_normvol_w
with open(os.path.join(thick_CalData, 'TAU_normvol_w.pkl'), 'rb') as f:
    TAU_normvol_w = pickle.load(f)
f.close()

# TDP_normvol_w
with open(os.path.join(thick_CalData, 'TDP_normvol_w.pkl'), 'rb') as f:
    TDP_normvol_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Thickness Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_thick_dict
with open(os.path.join(thick_CalData, 'cov_thick_dict.pkl'), 'rb') as f:
    cov_thick_dict = pickle.load(f)
f.close()

# cov_thick_z_dict
with open(os.path.join(thick_CalData, 'cov_thick_z_dict.pkl'), 'rb') as f:
    cov_thick_z_dict = pickle.load(f)
f.close()

# cov_thick_w_dict
with open(os.path.join(thick_CalData, 'cov_thick_w_dict.pkl'), 'rb') as f:
    cov_thick_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# ## Normalized Volume Covariance Matrices - Dictionaries (Original, Z, W Score)

# %%
# cov_normVol_dict
with open(os.path.join(thick_CalData, 'cov_normVol_dict.pkl'), 'rb') as f:
    cov_normVol_dict = pickle.load(f)
f.close()

# cov_normVol_z_dict
with open(os.path.join(thick_CalData, 'cov_normVol_z_dict.pkl'), 'rb') as f:
    cov_normVol_z_dict = pickle.load(f)
f.close()

# cov_normVol_w_dict
with open(os.path.join(thick_CalData, 'cov_normVol_w_dict.pkl'), 'rb') as f:
    cov_normVol_w_dict = pickle.load(f)
f.close()

# %% [markdown]
# # Draw Nodal Strength vs Thickness Values

# %% [markdown]
# ## Thickness Data - Original

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(thickHC, cov_thick_dict["HC"], 'FTD_Thickness_HC', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(thickTAU, cov_thick_dict["TAU"], 'FTD_Thickness_TAU', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(thickTDP, cov_thick_dict["TDP"], 'FTD_Thickness_TDP', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_Orig_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Thickness Data - Z Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_z, cov_thick_z_dict["HC"], 'FTD_Thickness_HC_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_z, cov_thick_z_dict["TAU"], 'FTD_Thickness_TAU_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_z, cov_thick_z_dict["TDP"], 'FTD_Thickness_TDP_ZScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_ZScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Thickness Data - W Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_w, cov_thick_w_dict["HC"], 'FTD_Thickness_HC_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_w, cov_thick_w_dict["TAU"], 'FTD_Thickness_TAU_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_w, cov_thick_w_dict["TDP"], 'FTD_Thickness_TDP_WScore', 'Degree', 'Mean Thickness', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_Thickness_WScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# # Draw Nodal Strength vs Normalized Volume Values

# %% [markdown]
# ## Normalized Volume Data - Original

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(normVolumeHC, cov_normVol_dict["HC"], 'FTD_NormVol_HC', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_Orig_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(normVolumeTAU, cov_normVol_dict["TAU"], 'FTD_NormVol_TAU', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_Orig_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(normVolumeTDP, cov_normVol_dict["TDP"], 'FTD_NormVol_TDP', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_Orig_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Normalized Volume Data - Z Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_normvol_z, cov_normVol_z_dict["HC"], 'FTD_NormVol_HC_ZScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_ZScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_normvol_z, cov_normVol_z_dict["TAU"], 'FTD_NormVol_TAU_ZScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_ZScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_normvol_z, cov_normVol_z_dict["TDP"], 'FTD_NormVol_TDP_ZScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_ZScore_(TDP)', 
                  linear_regression = True)

# %% [markdown]
# ## Normalized Volume Data - W Score

# %% [markdown]
# ### HC

# %%
ns.nonZeroDegCorr(HC_normvol_w, cov_normVol_w_dict["HC"], 'FTD_NormVol_HC_WScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_WScore_(HC)', 
                  linear_regression = True)

# %% [markdown]
# ### TAU

# %%
ns.nonZeroDegCorr(TAU_normvol_w, cov_normVol_w_dict["TAU"], 'FTD_NormVol_TAU_WScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_WScore_(TAU)', 
                  linear_regression = True)

# %% [markdown]
# ### TDP

# %%
ns.nonZeroDegCorr(TDP_normvol_w, cov_normVol_w_dict["TDP"], 'FTD_NormVol_TDP_WScore', 'Degree', 'Mean Normalized Volume', 
                  outputDir = thick_Fig, outputName = 'FTD_NodalStrength_NormVol_WScore_(TDP)', 
                  linear_regression = True)
