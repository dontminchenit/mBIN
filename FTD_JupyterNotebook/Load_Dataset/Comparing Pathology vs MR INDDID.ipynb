       120814.  ])

path_id_TDP = path_id_TDP.astype(int)

# %%
len(path_id_TAU)
# Out:
# 76

# %%
len(path_id_TDP)
# Out:
# 103

# %% [markdown]
# # MR INDDID

# %%
thick_id_HC = np.array(['100115', '100338', '100387', '100488', '100742', '101080',
       '102187', '102429', '102967', '102974', '103023', '103073',
       '103118', '103824', '104102', '105521', '105601', '106036',
       '106135', '106732', '106897', '107045', '107700', '108014',
       '108560', '108853', '108856', '109075', '109194', '109212',
       '109325', '109346', '109417', '109481', '110342', '111151',
       '111611', '112359', '112916', '113326', '115226', '115311',
       '115629', '116543', '117957', '117964', '118177', '118752',
       '118885', '119158', '119535', '119949', '120506', '124747'])

thick_id_HC = thick_id_HC.astype(int)

# %%
thick_id_TAU = np.array(['101483', '104093', '104190', '105564', '106309', '106814',
       '107516', '107677', '108026', '109300', '113113', '115001',
       '116591', '116607', '118064', '118148', '118410', '118780',
       '119089', '120594', '122104', '122375', '122376', '122419',
       '122601', '123352'])

thick_id_TAU = thick_id_TAU.astype(int)

# %%
thick_id_TDP = np.array(['101045', '104094', '104862', '105223', '108276', '108344',
       '108790', '109050', '109073', '109476', '112273', '112780',
       '112974', '114753', '115264', '117589', '117637', '118234',
       '118430', '118914', '119349', '119454', '119502', '120141',
       '120691', '120950', '121199', '122821', '124979', '125098'])

thick_id_TDP = thick_id_TDP.astype(int)

# %%
len(thick_id_HC)
# Out:
# 54

# %%
len(thick_id_TAU)
# Out:
# 26

# %%
len(thick_id_TDP)
# Out:
# 30

# %%
np.isin(thick_id_HC, path_id_TAU)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
np.isin(thick_id_HC, path_id_TDP)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
np.isin(thick_id_TAU, path_id_TAU)
# Out:
# array([ True, False, False,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True, False, False,  True,  True,
#        False, False, False, False, False, False, False, False])

# %%
np.isin(thick_id_TAU, path_id_TAU).sum()
# Out:
# 13

# %%
np.isin(thick_id_TAU, path_id_TDP)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
np.isin(thick_id_TDP, path_id_TDP)
# Out:
# array([ True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True, False,  True, False, False, False,  True,  True,
#        False, False, False])

# %%
np.isin(thick_id_TDP, path_id_TDP).sum()
# Out:
# 21

# %%
np.isin(thick_id_TDP, path_id_TAU)
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])
