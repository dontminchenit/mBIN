# %% [markdown]
# # Imports

# %%
import sys
import os
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import sexToBinary as sb
import wScore
import boxPlot as bp

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Formatted Layer Neuron Data (SMI32)

# %% [markdown]
# ### HC

# %%
# SMI32_HC_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_L.pkl'), 'rb') as f:
    SMI32_HC_L = pickle.load(f)
f.close()

# SMI32_HC_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_R.pkl'), 'rb') as f:
    SMI32_HC_R = pickle.load(f)
f.close()

# %%
SMI32_HC_L.shape
# Out:
# (18, 10)

# %%
SMI32_HC_R.shape
# Out:
# (14, 10)

# %% [markdown]
# ### Tau

# %%
# SMI32_Tau_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_L.pkl'), 'rb') as f:
    SMI32_Tau_L = pickle.load(f)
f.close()

# SMI32_Tau_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_R.pkl'), 'rb') as f:
    SMI32_Tau_R = pickle.load(f)
f.close()

# %%
SMI32_Tau_L.shape
# Out:
# (16, 10)

# %%
SMI32_Tau_R.shape
# Out:
# (17, 10)

# %% [markdown]
# ### TDP

# %%
# SMI32_TDP_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_L.pkl'), 'rb') as f:
    SMI32_TDP_L = pickle.load(f)
f.close()

# SMI32_TDP_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_R.pkl'), 'rb') as f:
    SMI32_TDP_R = pickle.load(f)
f.close()

# %%
SMI32_TDP_L.shape
# Out:
# (33, 10)

# %%
SMI32_TDP_R.shape
# Out:
# (28, 10)

# %% [markdown]
# ## Loading Age, Sex values

# %%
# SMI32_HC_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_Age_L.pkl'), 'rb') as f:
    SMI32_HC_Age_L = pickle.load(f)
f.close()
# SMI32_HC_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_Age_R.pkl'), 'rb') as f:
    SMI32_HC_Age_R = pickle.load(f)
f.close()
# SMI32_HC_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_Sex_L.pkl'), 'rb') as f:
    SMI32_HC_Sex_L = pickle.load(f)
f.close()
# SMI32_HC_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_Sex_R.pkl'), 'rb') as f:
    SMI32_HC_Sex_R = pickle.load(f)
f.close()

# SMI32_Tau_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Age_L.pkl'), 'rb') as f:
    SMI32_Tau_Age_L = pickle.load(f)
f.close()
# SMI32_Tau_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Age_R.pkl'), 'rb') as f:
    SMI32_Tau_Age_R = pickle.load(f)
f.close()
# SMI32_Tau_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Sex_L.pkl'), 'rb') as f:
    SMI32_Tau_Sex_L = pickle.load(f)
f.close()
# SMI32_Tau_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Sex_R.pkl'), 'rb') as f:
    SMI32_Tau_Sex_R = pickle.load(f)
f.close()

# SMI32_TDP_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Age_L.pkl'), 'rb') as f:
    SMI32_TDP_Age_L = pickle.load(f)
f.close()
# SMI32_TDP_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Age_R.pkl'), 'rb') as f:
    SMI32_TDP_Age_R = pickle.load(f)
f.close()
# SMI32_TDP_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Sex_L.pkl'), 'rb') as f:
    SMI32_TDP_Sex_L = pickle.load(f)
f.close()
# SMI32_TDP_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Sex_R.pkl'), 'rb') as f:
    SMI32_TDP_Sex_R = pickle.load(f)
f.close()

# %%
# SMI32_HC_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_HC_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_5_R = pickle.load(f)
f.close()

# %%
# SMI32_Tau_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_Tau_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_5_R = pickle.load(f)
f.close()

# %%
# SMI32_TDP_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_TDP_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_5_R = pickle.load(f)
f.close()

# %% [markdown]
# # Calculating W-Score

# %% [markdown]
# ## Format Age Values

# %%
ageHC_L = np.array(SMI32_HC_Age_L).reshape(-1, 1)
ageTau_L = np.array(SMI32_Tau_Age_L).reshape(-1, 1)
ageTDP_L = np.array(SMI32_TDP_Age_L).reshape(-1, 1)

ageHC_R = np.array(SMI32_HC_Age_R).reshape(-1, 1)
ageTau_R = np.array(SMI32_Tau_Age_R).reshape(-1, 1)
ageTDP_R = np.array(SMI32_TDP_Age_R).reshape(-1, 1)

# %% [markdown]
# ## Format Sex Values

# %%
sexHC_L = np.array(SMI32_HC_Sex_L).reshape(-1, 1)
sexTau_L = np.array(SMI32_Tau_Sex_L).reshape(-1, 1)
sexTDP_L = np.array(SMI32_TDP_Sex_L).reshape(-1, 1)

sexHC_R = np.array(SMI32_HC_Sex_R).reshape(-1, 1)
sexTau_R = np.array(SMI32_Tau_Sex_R).reshape(-1, 1)
sexTDP_R = np.array(SMI32_TDP_Sex_R).reshape(-1, 1)

# Convert Male --> 0 / Female --> 1
sexHC_L = np.array(sb.sexToBinary(sexHC_L)).reshape((-1, 1)) 
sexTau_L = np.array(sb.sexToBinary(sexTau_L)).reshape((-1, 1)) 
sexTDP_L = np.array(sb.sexToBinary(sexTDP_L)).reshape((-1, 1)) 

sexHC_R = np.array(sb.sexToBinary(sexHC_R)).reshape((-1, 1)) 
sexTau_R = np.array(sb.sexToBinary(sexTau_R)).reshape((-1, 1)) 
sexTDP_R = np.array(sb.sexToBinary(sexTDP_R)).reshape((-1, 1))

# %% [markdown]
# ## Format L1-6 values

# %%
SMI32_HC_NeuN_1_L = np.array(SMI32_HC_NeuN_1_L).reshape(-1, 1)
SMI32_HC_NeuN_2_L = np.array(SMI32_HC_NeuN_2_L).reshape(-1, 1)
SMI32_HC_NeuN_3_L = np.array(SMI32_HC_NeuN_3_L).reshape(-1, 1)
SMI32_HC_NeuN_4_L = np.array(SMI32_HC_NeuN_4_L).reshape(-1, 1)
SMI32_HC_NeuN_5_L = np.array(SMI32_HC_NeuN_5_L).reshape(-1, 1)
SMI32_HC_NeuN_1_R = np.array(SMI32_HC_NeuN_1_R).reshape(-1, 1)
SMI32_HC_NeuN_2_R = np.array(SMI32_HC_NeuN_2_R).reshape(-1, 1)
SMI32_HC_NeuN_3_R = np.array(SMI32_HC_NeuN_3_R).reshape(-1, 1)
SMI32_HC_NeuN_4_R = np.array(SMI32_HC_NeuN_4_R).reshape(-1, 1)
SMI32_HC_NeuN_5_R = np.array(SMI32_HC_NeuN_5_R).reshape(-1, 1)

SMI32_Tau_NeuN_1_L = np.array(SMI32_Tau_NeuN_1_L).reshape(-1, 1)
SMI32_Tau_NeuN_2_L = np.array(SMI32_Tau_NeuN_2_L).reshape(-1, 1)
SMI32_Tau_NeuN_3_L = np.array(SMI32_Tau_NeuN_3_L).reshape(-1, 1)
SMI32_Tau_NeuN_4_L = np.array(SMI32_Tau_NeuN_4_L).reshape(-1, 1)
SMI32_Tau_NeuN_5_L = np.array(SMI32_Tau_NeuN_5_L).reshape(-1, 1)
SMI32_Tau_NeuN_1_R = np.array(SMI32_Tau_NeuN_1_R).reshape(-1, 1)
SMI32_Tau_NeuN_2_R = np.array(SMI32_Tau_NeuN_2_R).reshape(-1, 1)
SMI32_Tau_NeuN_3_R = np.array(SMI32_Tau_NeuN_3_R).reshape(-1, 1)
SMI32_Tau_NeuN_4_R = np.array(SMI32_Tau_NeuN_4_R).reshape(-1, 1)
SMI32_Tau_NeuN_5_R = np.array(SMI32_Tau_NeuN_5_R).reshape(-1, 1)

SMI32_TDP_NeuN_1_L = np.array(SMI32_TDP_NeuN_1_L).reshape(-1, 1)
SMI32_TDP_NeuN_2_L = np.array(SMI32_TDP_NeuN_2_L).reshape(-1, 1)
SMI32_TDP_NeuN_3_L = np.array(SMI32_TDP_NeuN_3_L).reshape(-1, 1)
SMI32_TDP_NeuN_4_L = np.array(SMI32_TDP_NeuN_4_L).reshape(-1, 1)
SMI32_TDP_NeuN_5_L = np.array(SMI32_TDP_NeuN_5_L).reshape(-1, 1)
SMI32_TDP_NeuN_1_R = np.array(SMI32_TDP_NeuN_1_R).reshape(-1, 1)
SMI32_TDP_NeuN_2_R = np.array(SMI32_TDP_NeuN_2_R).reshape(-1, 1)
SMI32_TDP_NeuN_3_R = np.array(SMI32_TDP_NeuN_3_R).reshape(-1, 1)
SMI32_TDP_NeuN_4_R = np.array(SMI32_TDP_NeuN_4_R).reshape(-1, 1)
SMI32_TDP_NeuN_5_R = np.array(SMI32_TDP_NeuN_5_R).reshape(-1, 1)

# %% [markdown]
# ## Stack Age, Sex Values

# %%
# Stack the Age and Sex features into 2D array
hcCov_L_CT1 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_1_L), axis=1) 
hcCov_L_CT2 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_2_L), axis=1) 
hcCov_L_CT3 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_3_L), axis=1) 
hcCov_L_CT4 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_4_L), axis=1) 
hcCov_L_CT5 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_5_L), axis=1) 

tauCov_L_CT1 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_1_L), axis=1)  
tauCov_L_CT2 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_2_L), axis=1)  
tauCov_L_CT3 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_3_L), axis=1)  
tauCov_L_CT4 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_4_L), axis=1)  
tauCov_L_CT5 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_5_L), axis=1)  

tdpCov_L_CT1 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_1_L), axis=1)
tdpCov_L_CT2 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_2_L), axis=1)
tdpCov_L_CT3 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_3_L), axis=1)
tdpCov_L_CT4 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_4_L), axis=1)
tdpCov_L_CT5 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_5_L), axis=1)

# Stack the Age and Sex features into 2D array
hcCov_R_CT1 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_1_R), axis=1) 
hcCov_R_CT2 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_2_R), axis=1) 
hcCov_R_CT3 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_3_R), axis=1) 
hcCov_R_CT4 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_4_R), axis=1) 
hcCov_R_CT5 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_5_R), axis=1) 

tauCov_R_CT1 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_1_R), axis=1)
tauCov_R_CT2 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_2_R), axis=1)
tauCov_R_CT3 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_3_R), axis=1)
tauCov_R_CT4 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_4_R), axis=1)
tauCov_R_CT5 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_5_R), axis=1)

tdpCov_R_CT1 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_1_R), axis=1)
tdpCov_R_CT2 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_2_R), axis=1)
tdpCov_R_CT3 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_3_R), axis=1)
tdpCov_R_CT4 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_4_R), axis=1)
tdpCov_R_CT5 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_5_R), axis=1)

# %%
hcCov_R_CT1
# Out:
# array([[5.60000000e+01, 1.00000000e+00, 5.13162076e-02],
#        [8.30000000e+01, 1.00000000e+00, 7.43737798e-02],
#        [6.70000000e+01, 1.00000000e+00,            nan],
#        [7.00000000e+01, 1.00000000e+00, 3.82193393e-02],
#        [6.30000000e+01, 1.00000000e+00, 4.72280870e-02],
#        [6.20000000e+01, 0.00000000e+00,            nan],
#        [5.90000000e+01, 0.00000000e+00,            nan],
#        [7.50000000e+01, 1.00000000e+00,            nan],
#        [7.30000000e+01, 0.00000000e+00, 6.58627782e-02],
#        [6.90000000e+01, 0.00000000e+00,            nan],
#        [6.70000000e+01, 1.00000000e+00, 5.45694689e-02],
#        [6.00000000e+01, 1.00000000e+00, 5.99692718e-02],
#        [6.40000000e+01, 1.00000000e+00, 5.69709177e-02],
#        [7.20000000e+01, 0.00000000e+00, 7.38519302e-02]])

# %% [markdown]
# ## Divide HC, Tau, TDP into Cortical Types

# %%
SMI32_HC_L_CT1 = SMI32_HC_L[:, [0, 0+5]]
SMI32_HC_L_CT2 = SMI32_HC_L[:, [1, 1+5]]
SMI32_HC_L_CT3 = SMI32_HC_L[:, [2, 2+5]]
SMI32_HC_L_CT4 = SMI32_HC_L[:, [3, 3+5]]
SMI32_HC_L_CT5 = SMI32_HC_L[:, [4, 4+5]]

SMI32_Tau_L_CT1 = SMI32_Tau_L[:, [0, 0+5]]
SMI32_Tau_L_CT2 = SMI32_Tau_L[:, [1, 1+5]]
SMI32_Tau_L_CT3 = SMI32_Tau_L[:, [2, 2+5]]
SMI32_Tau_L_CT4 = SMI32_Tau_L[:, [3, 3+5]]
SMI32_Tau_L_CT5 = SMI32_Tau_L[:, [4, 4+5]]

SMI32_TDP_L_CT1 = SMI32_TDP_L[:, [0, 0+5]]
SMI32_TDP_L_CT2 = SMI32_TDP_L[:, [1, 1+5]]
SMI32_TDP_L_CT3 = SMI32_TDP_L[:, [2, 2+5]]
SMI32_TDP_L_CT4 = SMI32_TDP_L[:, [3, 3+5]]
SMI32_TDP_L_CT5 = SMI32_TDP_L[:, [4, 4+5]]

# %%
SMI32_HC_R_CT1 = SMI32_HC_R[:, [0, 0+5]]
SMI32_HC_R_CT2 = SMI32_HC_R[:, [1, 1+5]]
SMI32_HC_R_CT3 = SMI32_HC_R[:, [2, 2+5]]
SMI32_HC_R_CT4 = SMI32_HC_R[:, [3, 3+5]]
SMI32_HC_R_CT5 = SMI32_HC_R[:, [4, 4+5]]

SMI32_Tau_R_CT1 = SMI32_Tau_R[:, [0, 0+5]]
SMI32_Tau_R_CT2 = SMI32_Tau_R[:, [1, 1+5]]
SMI32_Tau_R_CT3 = SMI32_Tau_R[:, [2, 2+5]]
SMI32_Tau_R_CT4 = SMI32_Tau_R[:, [3, 3+5]]
SMI32_Tau_R_CT5 = SMI32_Tau_R[:, [4, 4+5]]

SMI32_TDP_R_CT1 = SMI32_TDP_R[:, [0, 0+5]]
SMI32_TDP_R_CT2 = SMI32_TDP_R[:, [1, 1+5]]
SMI32_TDP_R_CT3 = SMI32_TDP_R[:, [2, 2+5]]
SMI32_TDP_R_CT4 = SMI32_TDP_R[:, [3, 3+5]]
SMI32_TDP_R_CT5 = SMI32_TDP_R[:, [4, 4+5]]

# %% [markdown]
# ## Number of regions we are analyzing (N = 10)

# %%
#N = SMI32_HC_L.shape[1]
N=2

# %% [markdown]
# ## Calculate the W-Scores

# %%
# L
## CT1
SMI32_HC_w_L_CT1, SMI32_Tau_w_L_CT1, SMI32_TDP_w_L_CT1 = wScore.generateWScore(hcCov_L_CT1, tauCov_L_CT1, tdpCov_L_CT1, 
                                                                            N, 
                                                                            SMI32_HC_L_CT1, 
                                                                            SMI32_Tau_L_CT1,  
                                                                            SMI32_TDP_L_CT1)
## CT2
SMI32_HC_w_L_CT2, SMI32_Tau_w_L_CT2, SMI32_TDP_w_L_CT2 = wScore.generateWScore(hcCov_L_CT2, tauCov_L_CT2, tdpCov_L_CT2, 
                                                                            N, 
                                                                            SMI32_HC_L_CT2, 
                                                                            SMI32_Tau_L_CT2,  
                                                                            SMI32_TDP_L_CT2)
## CT3
SMI32_HC_w_L_CT3, SMI32_Tau_w_L_CT3, SMI32_TDP_w_L_CT3 = wScore.generateWScore(hcCov_L_CT3, tauCov_L_CT3, tdpCov_L_CT3, 
                                                                            N, 
                                                                            SMI32_HC_L_CT3, 
                                                                            SMI32_Tau_L_CT3,  
                                                                            SMI32_TDP_L_CT3)
## CT4
SMI32_HC_w_L_CT4, SMI32_Tau_w_L_CT4, SMI32_TDP_w_L_CT4 = wScore.generateWScore(hcCov_L_CT4, tauCov_L_CT4, tdpCov_L_CT4, 
                                                                            N, 
                                                                            SMI32_HC_L_CT4, 
                                                                            SMI32_Tau_L_CT4,  
                                                                            SMI32_TDP_L_CT4)
## CT5
SMI32_HC_w_L_CT5, SMI32_Tau_w_L_CT5, SMI32_TDP_w_L_CT5 = wScore.generateWScore(hcCov_L_CT5, tauCov_L_CT5, tdpCov_L_CT5, 
                                                                            N, 
                                                                            SMI32_HC_L_CT5, 
                                                                            SMI32_Tau_L_CT5,  
                                                                            SMI32_TDP_L_CT5)

# %%
SMI32_HC_w_L = np.zeros(SMI32_HC_L.shape)
SMI32_Tau_w_L = np.zeros(SMI32_Tau_L.shape)
SMI32_TDP_w_L = np.zeros(SMI32_TDP_L.shape)

for i in range(5):
    if i == 0:
        SMI32_HC_w_L[:, [i, i+5]] = SMI32_HC_w_L_CT1
        SMI32_Tau_w_L[:, [i, i+5]] = SMI32_Tau_w_L_CT1
        SMI32_TDP_w_L[:, [i, i+5]] = SMI32_TDP_w_L_CT1
        
    elif i == 1:
        SMI32_HC_w_L[:, [i, i+5]] = SMI32_HC_w_L_CT2
        SMI32_Tau_w_L[:, [i, i+5]] = SMI32_Tau_w_L_CT2
        SMI32_TDP_w_L[:, [i, i+5]] = SMI32_TDP_w_L_CT2
        
    elif i == 2:
        SMI32_HC_w_L[:, [i, i+5]] = SMI32_HC_w_L_CT3
        SMI32_Tau_w_L[:, [i, i+5]] = SMI32_Tau_w_L_CT3
        SMI32_TDP_w_L[:, [i, i+5]] = SMI32_TDP_w_L_CT3
        
    elif i == 3:
        SMI32_HC_w_L[:, [i, i+5]] = SMI32_HC_w_L_CT4
        SMI32_Tau_w_L[:, [i, i+5]] = SMI32_Tau_w_L_CT4
        SMI32_TDP_w_L[:, [i, i+5]] = SMI32_TDP_w_L_CT4
        
    else:
        SMI32_HC_w_L[:, [i, i+5]] = SMI32_HC_w_L_CT5
        SMI32_Tau_w_L[:, [i, i+5]] = SMI32_Tau_w_L_CT5
        SMI32_TDP_w_L[:, [i, i+5]] = SMI32_TDP_w_L_CT5

# %%
# R
## CT1
SMI32_HC_w_R_CT1, SMI32_Tau_w_R_CT1, SMI32_TDP_w_R_CT1 = wScore.generateWScore(hcCov_R_CT1, tauCov_R_CT1, tdpCov_R_CT1, 
                                                                            N, 
                                                                            SMI32_HC_R_CT1, 
                                                                            SMI32_Tau_R_CT1,  
                                                                            SMI32_TDP_R_CT1)
## CT2
SMI32_HC_w_R_CT2, SMI32_Tau_w_R_CT2, SMI32_TDP_w_R_CT2 = wScore.generateWScore(hcCov_R_CT2, tauCov_R_CT2, tdpCov_R_CT2, 
                                                                            N, 
                                                                            SMI32_HC_R_CT2, 
                                                                            SMI32_Tau_R_CT2,  
                                                                            SMI32_TDP_R_CT2)
## CT3
SMI32_HC_w_R_CT3, SMI32_Tau_w_R_CT3, SMI32_TDP_w_R_CT3 = wScore.generateWScore(hcCov_R_CT3, tauCov_R_CT3, tdpCov_R_CT3, 
                                                                            N, 
                                                                            SMI32_HC_R_CT3, 
                                                                            SMI32_Tau_R_CT3,  
                                                                            SMI32_TDP_R_CT3)
## CT4
SMI32_HC_w_R_CT4, SMI32_Tau_w_R_CT4, SMI32_TDP_w_R_CT4 = wScore.generateWScore(hcCov_R_CT4, tauCov_R_CT4, tdpCov_R_CT4, 
                                                                            N, 
                                                                            SMI32_HC_R_CT4, 
                                                                            SMI32_Tau_R_CT4,  
                                                                            SMI32_TDP_R_CT4)
## CT5
SMI32_HC_w_R_CT5, SMI32_Tau_w_R_CT5, SMI32_TDP_w_R_CT5 = wScore.generateWScore(hcCov_R_CT5, tauCov_R_CT5, tdpCov_R_CT5, 
                                                                            N, 
                                                                            SMI32_HC_R_CT5, 
                                                                            SMI32_Tau_R_CT5,  
                                                                            SMI32_TDP_R_CT5)

# %%
SMI32_HC_w_R = np.zeros(SMI32_HC_R.shape)
SMI32_Tau_w_R = np.zeros(SMI32_Tau_R.shape)
SMI32_TDP_w_R = np.zeros(SMI32_TDP_R.shape)

for i in range(5):
    if i == 0:
        SMI32_HC_w_R[:, [i, i+5]] = SMI32_HC_w_R_CT1
        SMI32_Tau_w_R[:, [i, i+5]] = SMI32_Tau_w_R_CT1
        SMI32_TDP_w_R[:, [i, i+5]] = SMI32_TDP_w_R_CT1
        
    elif i == 1:
        SMI32_HC_w_R[:, [i, i+5]] = SMI32_HC_w_R_CT2
        SMI32_Tau_w_R[:, [i, i+5]] = SMI32_Tau_w_R_CT2
        SMI32_TDP_w_R[:, [i, i+5]] = SMI32_TDP_w_R_CT2
        
    elif i == 2:
        SMI32_HC_w_R[:, [i, i+5]] = SMI32_HC_w_R_CT3
        SMI32_Tau_w_R[:, [i, i+5]] = SMI32_Tau_w_R_CT3
        SMI32_TDP_w_R[:, [i, i+5]] = SMI32_TDP_w_R_CT3
        
    elif i == 3:
        SMI32_HC_w_R[:, [i, i+5]] = SMI32_HC_w_R_CT4
        SMI32_Tau_w_R[:, [i, i+5]] = SMI32_Tau_w_R_CT4
        SMI32_TDP_w_R[:, [i, i+5]] = SMI32_TDP_w_R_CT4
        
    else:
        SMI32_HC_w_R[:, [i, i+5]] = SMI32_HC_w_R_CT5
        SMI32_Tau_w_R[:, [i, i+5]] = SMI32_Tau_w_R_CT5
        SMI32_TDP_w_R[:, [i, i+5]] = SMI32_TDP_w_R_CT5

# %%
pd.DataFrame(SMI32_Tau_L)
# Out:
#            0         1         2         3         4         5         6  \
# 0        NaN -3.094578       NaN -3.181728 -2.894277       NaN -2.464085
# 1  -5.304286 -5.182883 -4.544291 -5.451369 -5.690564 -4.144141 -3.678674
# 2  -6.417769 -5.908697 -5.009377 -5.665035       NaN -4.444993 -4.093610
# 3        NaN -8.380458 -7.081581 -4.835629 -7.468945       NaN -5.429166
# 4  -5.183889 -5.761138 -4.618606 -4.788292 -6.045480 -3.906007 -3.809780
# 5  -6.148435 -5.619042 -7.415564 -7.113548 -8.048596 -5.013718 -4.775518
# 6  -7.003123 -7.079118       NaN       NaN -7.185288 -4.158393 -5.169797
# 7        NaN -6.377762 -6.152816       NaN       NaN       NaN -5.260417
# 8  -5.731466 -4.893575 -4.420449 -7.294100 -4.799292 -5.243446 -4.964216
# 9  -5.753957 -5.181216 -4.932081       NaN       NaN -5.034868 -4.883942
# 10 -6.741396 -5.483352 -5.281179 -5.950804 -4.986421 -5.102466 -4.752259
# 11 -6.823848 -5.706672       NaN       NaN -4.500026 -4.119509 -4.423190
# 12 -6.635803 -7.102392 -6.264462 -4.282832 -5.009280 -5.160492 -4.912625
# 13 -6.569332 -6.398813 -6.797529 -6.506410 -6.823844 -4.776135 -5.488873
# 14       NaN       NaN       NaN -5.197287 -5.460768       NaN       NaN
# 15 -5.522224 -5.148550 -4.613587 -4.757265 -4.926303 -4.357785 -4.078380
#
#            7         8         9
# 0        NaN -2.621670 -2.895668
# 1  -3.493422 -4.475262 -5.271510
# 2  -3.971748 -4.905717 -2.713530
# 3  -5.443024 -4.252499 -6.706624
# 4  -3.440324 -4.342116 -5.892427
# 5  -5.833114 -5.608648 -8.127046
# 6        NaN       NaN -5.992493
# 7  -5.408819       NaN       NaN
# 8  -4.151461 -8.512431 -4.477476
# 9  -3.870540       NaN       NaN
# 10 -5.417070 -5.998062 -3.839640
# 11       NaN       NaN -4.876490
# 12 -5.192071 -3.982845 -4.823679
# 13 -5.595759 -5.291933 -6.493013
# 14       NaN -5.648463 -4.777986
# 15 -4.250367 -3.969320 -3.829849

# %%
pd.DataFrame(SMI32_Tau_w_L)
# Out:
#            0         1         2         3         4         5         6  \
# 0        NaN  3.768789       NaN  2.713108  2.699989       NaN  2.938382
# 1   0.747415  0.015258 -0.300336 -1.541865 -3.764108 -1.434227  0.308398
# 2   0.037806 -0.101865  0.015815 -1.789535       NaN -1.990992  0.140811
# 3        NaN -2.211211 -1.369583  1.951417 -5.454634       NaN -2.263129
# 4   0.561730 -0.336127  0.710953  0.273616 -3.944124 -0.629048 -0.578682
# 5   0.845788  1.660592 -1.549764 -0.291532 -5.943281 -3.211399 -1.058753
# 6  -0.542356 -2.258522       NaN       NaN -5.551123 -1.050706 -2.940498
# 7        NaN -0.859000 -0.449649       NaN       NaN       NaN -3.321776
# 8   0.838134  1.418400  0.313427 -2.875508 -0.848280 -2.964679 -1.484085
# 9   0.865721  0.354381  0.004095       NaN       NaN -2.664378 -2.337175
# 10 -0.854985 -0.030551 -0.695896 -1.358052 -1.480082 -3.149415 -1.435249
# 11 -0.545934 -0.348617       NaN       NaN -1.158383 -0.922649 -1.075839
# 12 -1.519803 -3.007862 -2.894703 -1.707146 -4.483305 -2.676469 -2.351491
# 13 -0.415725 -1.721402 -2.758071 -2.945658 -5.871951 -2.102646 -3.468801
# 14       NaN       NaN       NaN  0.073326 -2.307374       NaN       NaN
# 15 -0.386654 -0.552134 -0.647426 -0.605730 -2.871606 -1.762211 -0.824035
#
#            7         8         9
# 0        NaN  2.246979  3.959923
# 1   0.106179 -0.864667 -3.643832
# 2  -0.867420 -1.470371  4.522202
# 3  -2.551692  0.747966 -2.958815
# 4   0.153684 -0.990840 -6.129909
# 5  -2.752437 -1.063375 -6.688953
# 6        NaN       NaN -1.625200
# 7  -2.344404       NaN       NaN
# 8  -1.083075 -6.114081  2.126645
# 9  -0.430930       NaN       NaN
# 10 -2.496860 -2.483932  3.669954
# 11       NaN       NaN -2.613743
# 12 -2.301430 -1.233869 -8.418434
# 13 -2.754804 -2.220881 -6.384395
# 14       NaN -1.660889  1.638546
# 15 -0.802508 -0.042876 -1.160932

# %% [markdown]
# # Show Data Distribution Before and After W-Score

# %% [markdown]
# ## Before

# %%
bp.drawthicknessboxplot(SMI32_HC_L, SMI32_Tau_L, SMI32_TDP_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32).png")

# %%
bp.drawthicknessboxplot(SMI32_HC_R, SMI32_Tau_R, SMI32_TDP_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32).png")

# %% [markdown]
# ## After

# %%
SMI32_HC_w_L
# Out:
# array([[-0.67260241, -0.90502839, -0.69120111, -0.71389988,         nan,
#         -1.24823151, -2.20909169, -1.4649972 , -2.11080744,         nan],
#        [        nan,         nan, -1.16057763, -0.64054204, -1.07297699,
#                 nan,         nan,  0.30562958,  0.15764648, -1.03386253],
#        [        nan,  0.9883053 ,  0.73975895,  1.59694863,         nan,
#                 nan,  0.49480919,  0.04938009,  1.28563392,         nan],
#        [ 0.2365247 ,  0.18363555,  0.89997186,  0.59982411,         nan,
#          0.77842716,  1.05538777,  1.01790357,  1.251692  ,         nan],
#        [ 0.82586894,  0.53968559,         nan,         nan,         nan,
#         -0.09075378, -0.02508521,         nan,         nan,         nan],
#        [ 0.07140421,  1.57713635,  1.9656649 ,  0.04079506,         nan,
#          0.23631566,  0.8689787 ,  0.93874299, -0.316379  ,         nan],
#        [-0.93117003, -2.14920575, -2.54339854, -2.58777455, -0.99429051,
#         -1.45425776, -1.6074377 , -2.14476108, -1.68297268, -0.18362186],
#        [ 0.95563671,  0.54476527,  0.79915336,         nan,  1.04905041,
#          0.85271576,  1.39977248,  1.10582899,         nan,  0.73369136],
#        [ 0.1042516 , -0.07434334,  0.59667882,  1.46298596,  0.70476444,
#          1.23518419,  1.12594786,  0.98571168,  1.35458264,  0.85003913],
#        [-0.27043627,  0.7081058 ,         nan,         nan, -1.45071945,
#         -0.78660612,  0.00295932,         nan,         nan, -1.11868885],
#        [ 2.67361648,  1.87121733,  0.66447123,  0.6299861 , -0.87303941,
#          1.58711781,  0.68957667,  0.71851154,  0.59910439, -1.03501748],
#        [        nan,         nan, -0.79236067,  0.27467017, -0.11409183,
#                 nan,         nan, -1.7759461 , -0.6662371 , -0.69446198],
#        [        nan, -0.55912422, -0.17876399,  0.22171352,  1.42410964,
#                 nan, -0.9178658 ,  0.21527711,  0.19458781,  1.26184679],
#        [        nan,  0.16058333, -0.04882611,         nan,         nan,
#                 nan,  0.50872891,  0.26467499,         nan,         nan],
#        [-0.28008639, -0.53570975,  0.08986866, -0.19978271,  1.77828875,
#          0.81649285,  0.37962275,  0.36592221,  0.23042412,  1.90370659],
#        [-1.23448743, -0.77689472,  0.07955809, -0.07644816, -0.43664768,
#         -1.56612014, -0.95933014,  0.16791782, -0.2146794 ,  0.22960627],
#        [-0.95896112, -0.76145063,  0.16710761,  0.23385461, -0.03837396,
#          0.02262728, -0.06609536,  0.26394884,  0.50156921, -1.21340862],
#        [-0.519559  , -0.81167773, -0.58710543, -0.84233081,  0.02392658,
#         -0.38291141, -0.74087775, -1.01374503, -0.58416495,  0.30017117]])

# %%
bp.drawthicknessboxplot(SMI32_HC_w_L, SMI32_Tau_w_L, SMI32_TDP_w_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32)_WScore.png")

# %%
bp.drawthicknessboxplot(SMI32_HC_w_R, SMI32_Tau_w_R, SMI32_TDP_w_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32)_WScore.png")

# %%
# ln_L56_1
SMI32_HC_w_L[:, 5]
# Out:
# array([-1.24823151,         nan,         nan,  0.77842716, -0.09075378,
#         0.23631566, -1.45425776,  0.85271576,  1.23518419, -0.78660612,
#         1.58711781,         nan,         nan,         nan,  0.81649285,
#        -1.56612014,  0.02262728, -0.38291141])

# %%
# ln_L23_2
SMI32_HC_w_L[:, 1]
# Out:
# array([-0.90502839,         nan,  0.9883053 ,  0.18363555,  0.53968559,
#         1.57713635, -2.14920575,  0.54476527, -0.07434334,  0.7081058 ,
#         1.87121733,         nan, -0.55912422,  0.16058333, -0.53570975,
#        -0.77689472, -0.76145063, -0.81167773])

# %%
# ln_L56_1
SMI32_Tau_w_L[:, 5]
# Out:
# array([        nan, -1.43422658, -1.99099235,         nan, -0.62904788,
#        -3.21139909, -1.0507065 ,         nan, -2.9646788 , -2.66437793,
#        -3.14941545, -0.92264918, -2.67646888, -2.10264567,         nan,
#        -1.76221113])

# %%
# ln_L23_2
SMI32_Tau_w_L[:, 1]
# Out:
# array([ 3.76878904,  0.01525822, -0.10186497, -2.21121055, -0.3361274 ,
#         1.66059224, -2.25852162, -0.85900017,  1.4183996 ,  0.35438116,
#        -0.03055094, -0.34861674, -3.00786237, -1.7214024 ,         nan,
#        -0.55213383])

# %% [markdown]
# # Saving

# %%
# SMI32_HC_w_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_HC_w_L, f)
f.close()

# SMI32_Tau_w_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_Tau_w_L, f)
f.close()

# SMI32_TDP_w_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_TDP_w_L, f)
f.close()

# %%
# SMI32_HC_w_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_HC_w_R, f)
f.close()

# SMI32_Tau_w_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_Tau_w_R, f)
f.close()

# SMI32_TDP_w_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_TDP_w_L, f)
f.close()

# %%
data = SMI32_HC_L

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_HC_w_L
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_HC_R

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / RIGHT):")
print(nan_count_per_column)

data = SMI32_HC_w_R
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / RIGHT):")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column (BEFORE W-Score / LEFT):
# [5 2 2 4 6 5 2 2 4 6]
# Number of NaN values in each column (AFTER W-Score / LEFT):
# [5 2 2 4 6 5 2 2 4 6]
# Number of NaN values in each column (BEFORE W-Score / RIGHT):
# [5 1 0 0 6 5 1 0 0 6]
# Number of NaN values in each column (AFTER W-Score / RIGHT):
# [5 1 0 0 6 5 1 0 0 6]

# %%
data = SMI32_Tau_L

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_Tau_w_L
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_Tau_R

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / RIGHT):")
print(nan_count_per_column)

data = SMI32_Tau_w_R
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / RIGHT):")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column (BEFORE W-Score / LEFT):
# [4 1 4 4 3 4 1 4 4 2]
# Number of NaN values in each column (AFTER W-Score / LEFT):
# [4 1 4 4 3 4 1 4 4 2]
# Number of NaN values in each column (BEFORE W-Score / RIGHT):
# [7 4 5 1 6 7 4 5 1 6]
# Number of NaN values in each column (AFTER W-Score / RIGHT):
# [7 4 5 1 6 7 4 5 1 6]

# %%
data = SMI32_TDP_L

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_TDP_w_L
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / LEFT):")
print(nan_count_per_column)

data = SMI32_TDP_R

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score / RIGHT):")
print(nan_count_per_column)

data = SMI32_TDP_w_R
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score / RIGHT):")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column (BEFORE W-Score / LEFT):
# [13  4  4  1  3 13  4  4  1  3]
# Number of NaN values in each column (AFTER W-Score / LEFT):
# [13  4  4  1  3 13  4  4  1  3]
# Number of NaN values in each column (BEFORE W-Score / RIGHT):
# [14  6 12  3  9 14  6 12  3  9]
# Number of NaN values in each column (AFTER W-Score / RIGHT):
# [14  6 12  3  9 14  6 12  3  9]
