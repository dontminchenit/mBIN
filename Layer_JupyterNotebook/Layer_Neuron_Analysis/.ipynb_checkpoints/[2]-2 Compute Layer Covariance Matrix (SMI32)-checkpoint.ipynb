# %% [markdown]
# # Imports

# %%
import sys
import os
import pickle
import numpy as np

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)

import covariance as c
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# %% [markdown]
# # Loading Formatted Layer Neuron Data (SMI32)

# %% [markdown]
# ## HC

# %%
# SMI32_HC
with open(os.path.join(layer_dataDir, 'SMI32_HC.pkl'), 'rb') as f:
    SMI32_HC = pickle.load(f)
f.close()

# %%
SMI32_HC.shape
# Out:
# (32, 10)

# %% [markdown]
# ## Tau

# %%
# SMI32_Tau
with open(os.path.join(layer_dataDir, 'SMI32_Tau.pkl'), 'rb') as f:
    SMI32_Tau = pickle.load(f)
f.close()

# %%
SMI32_Tau.shape
# Out:
# (28, 10)

# %% [markdown]
# ## TDP

# %%
# SMI32_TDP
with open(os.path.join(layer_dataDir, 'SMI32_TDP.pkl'), 'rb') as f:
    SMI32_TDP = pickle.load(f)
f.close()

# %%
SMI32_TDP.shape
# Out:
# (50, 10)

# %% [markdown]
# # Set Parameters

# %% [markdown]
# ## p-value threshold

# %%
# pthresh_list = [0.05]
pthresh = 0.05

# %% [markdown]
# ## Covariance Matrix Threshold (to remove noise)

# %%
cov_thresh = 0.1

# %% [markdown]
# # Calculate Covariance Matrices (SMI32)

# %% [markdown]
# ## HC, Tau, TDP, Tau < HC, Tau > HC, TDP < HC, TDP > HC, Tau > TDP, TDP > Tau

# %%
cov_SMI32_dict = c.calCovMatDict(SMI32_HC, SMI32_Tau, SMI32_TDP, pthresh, cov_thresh)

# %%
import pandas as pd
pd.DataFrame(SMI32_Tau)
# Out:
#            0         1         2         3         4         5         6  \
# 0        NaN -5.954105       NaN       NaN       NaN       NaN -4.738629
# 1        NaN -3.094578       NaN -3.181728 -2.894277       NaN -2.464085
# 2  -5.304286 -5.182883 -4.544291 -5.451369 -5.690564 -4.144141 -3.678674
# 3  -6.417769 -5.908697 -5.009377 -5.665035       NaN -4.444993 -4.093610
# 4  -4.469255 -5.417048 -4.582560 -5.138158       NaN -4.006567 -5.224348
# 5        NaN -8.380458 -7.081581 -4.835629 -7.468945       NaN -5.429166
# 6        NaN       NaN -5.361948 -6.421670 -7.578867       NaN       NaN
# 7  -5.209778 -5.907917 -4.761861 -5.837456 -6.350895 -4.285047 -4.145690
# 8  -5.693346 -5.920475 -5.095699 -4.431667 -7.400610 -4.325701 -4.346627
# 9  -5.183889 -5.761138 -4.618606 -4.788292 -6.045480 -3.906007 -3.809780
# 10 -7.459292 -6.380637 -6.592258 -6.479587 -4.652500 -5.037017 -4.992591
# 11 -6.148435 -5.619042 -7.415564 -7.113548 -8.048596 -5.013718 -4.775518
# 12       NaN -5.973536 -6.560182 -4.557551 -6.784684       NaN -5.517997
# 13 -7.003123 -7.079118       NaN       NaN -7.185288 -4.158393 -5.169797
# 14       NaN -7.052589 -4.803584 -5.823348 -6.170200       NaN -5.573356
# 15 -5.764074 -5.424852 -4.746214 -4.189469 -4.405956 -4.426995 -4.568953
# 16       NaN -6.377762 -6.499913 -6.392433 -6.740405       NaN -5.260417
# 17 -6.193296 -5.155011 -4.420449 -6.892138 -4.799292 -4.931803 -5.310994
# 18 -5.753957 -5.181216 -4.932081 -4.484405 -6.695288 -5.034868 -4.883942
# 19 -7.371362 -6.664205 -5.423666 -5.608707 -4.731021 -4.093431 -5.071886
# 20 -6.741396 -5.483352 -5.281179 -5.950804 -4.986421 -5.102466 -4.752259
# 21 -7.127960 -8.293433 -6.989496 -6.087255 -7.193922 -6.435203 -6.546068
# 22 -6.823848 -5.706672       NaN -5.540827 -4.500026 -4.119509 -4.423190
# 23 -6.217621 -6.607188 -5.882459 -4.378905 -5.009280 -4.756757 -4.612948
# 24 -6.569332 -6.398813 -6.797529 -6.506410 -6.823844 -4.776135 -5.488873
# 25       NaN       NaN       NaN -5.197287 -5.460768       NaN       NaN
# 26 -6.770262 -7.921497       NaN -6.409148 -7.702237 -5.097454 -5.608214
# 27 -5.868533 -4.721390 -4.613587 -4.607868 -4.926303 -4.453227 -3.963876
#
#            7         8         9
# 0        NaN       NaN       NaN
# 1        NaN -2.621670 -2.895668
# 2  -3.493422 -4.475262 -5.271510
# 3  -3.971748 -4.905717 -2.713530
# 4  -4.058375 -5.452720       NaN
# 5  -5.443024 -4.252499 -6.706624
# 6  -5.732809 -6.996435 -8.254816
# 7  -3.925728 -4.749038 -5.527341
# 8  -4.225238 -4.078202 -5.411537
# 9  -3.440324 -4.342116 -5.892427
# 10 -5.599389 -6.124409 -3.966437
# 11 -5.833114 -5.608648 -8.127046
# 12 -4.649891 -5.022636 -5.810529
# 13       NaN       NaN -5.992493
# 14 -4.778009 -5.325946 -6.550163
# 15 -3.698748 -2.930263 -3.343036
# 16 -6.183487 -5.545807 -8.108732
# 17 -4.151461 -7.451189 -4.477476
# 18 -3.870540 -4.719080 -6.110540
# 19 -4.031571 -4.530171 -4.148333
# 20 -5.417070 -5.998062 -3.839640
# 21 -6.537083 -5.946525 -7.115636
# 22       NaN -5.661539 -4.876490
# 23 -4.736957 -3.986644 -4.823679
# 24 -5.595759 -5.291933 -6.493013
# 25       NaN -5.648463 -4.777986
# 26       NaN -6.492230 -6.273347
# 27 -4.250367 -4.230338 -3.829849

# %% [markdown]
# # Saving

# %%
# cov_SMI32_dict
with open(os.path.join(layer_CalData, 'cov_SMI32_dict.pkl'), 'wb') as f:
    pickle.dump(cov_SMI32_dict, f)
f.close()
