# %% [markdown]
# # Import

# %%
import sys
import os
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Covariance Matrices

# %%
# cov_NeuN_dict_L
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_L.pkl'), 'rb') as f:
    cov_NeuN_dict_L = pickle.load(f)
f.close()

# cov_NeuN_dict_R
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_R.pkl'), 'rb') as f:
    cov_NeuN_dict_R = pickle.load(f)
f.close()

# %%
# cov_NeuN_dict_w_L
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_w_L.pkl'), 'rb') as f:
    cov_NeuN_dict_w_L = pickle.load(f)
f.close()

# cov_NeuN_dict_w_R
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_w_R.pkl'), 'rb') as f:
    cov_NeuN_dict_w_R = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Layer Neuron Labels (NeuN)

# %%
# NeuN_Labels
with open(os.path.join(layer_dataDir, 'NeuN_Labels.pkl'), 'rb') as f:
    NeuN_Labels = pickle.load(f)
f.close()

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) Left Hemisphere

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_L['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) Right

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_R['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) W Score - Left

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_w_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_w_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_w_L (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_L['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau w _L(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) W Score - Right

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_w_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_w_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_w_R (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_R['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau w _R(covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)
