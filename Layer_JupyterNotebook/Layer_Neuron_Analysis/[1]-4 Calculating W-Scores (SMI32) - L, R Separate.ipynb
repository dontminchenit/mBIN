# %% [markdown]
# # Imports

# %%
import sys
import os
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import sexToBinary as sb
import wScore
import boxPlot as bp

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Formatted Layer Neuron Data (SMI32)

# %% [markdown]
# ### HC

# %%
# SMI32_HC_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_L.pkl'), 'rb') as f:
    SMI32_HC_L = pickle.load(f)
f.close()

# SMI32_HC_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_R.pkl'), 'rb') as f:
    SMI32_HC_R = pickle.load(f)
f.close()

# %%
SMI32_HC_L.shape
# Out:
# (18, 12)

# %%
SMI32_HC_R.shape
# Out:
# (14, 12)

# %% [markdown]
# ### Tau

# %%
# SMI32_Tau_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_L.pkl'), 'rb') as f:
    SMI32_Tau_L = pickle.load(f)
f.close()

# SMI32_Tau_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_R.pkl'), 'rb') as f:
    SMI32_Tau_R = pickle.load(f)
f.close()

# %%
SMI32_Tau_L.shape
# Out:
# (16, 12)

# %%
SMI32_Tau_R.shape
# Out:
# (17, 12)

# %% [markdown]
# ### TDP

# %%
# SMI32_TDP_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_L.pkl'), 'rb') as f:
    SMI32_TDP_L = pickle.load(f)
f.close()

# SMI32_TDP_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_R.pkl'), 'rb') as f:
    SMI32_TDP_R = pickle.load(f)
f.close()

# %%
SMI32_TDP_L.shape
# Out:
# (33, 12)

# %%
SMI32_TDP_R.shape
# Out:
# (28, 12)

# %% [markdown]
# ## Loading Age, Sex, L1-6_SMI32, ADNC values

# %%
# SMI32_HC_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_Age_L.pkl'), 'rb') as f:
    SMI32_HC_Age_L = pickle.load(f)
f.close()
# SMI32_HC_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_Age_R.pkl'), 'rb') as f:
    SMI32_HC_Age_R = pickle.load(f)
f.close()
# SMI32_HC_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_Sex_L.pkl'), 'rb') as f:
    SMI32_HC_Sex_L = pickle.load(f)
f.close()
# SMI32_HC_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_Sex_R.pkl'), 'rb') as f:
    SMI32_HC_Sex_R = pickle.load(f)
f.close()
# SMI32_HC_ADNC_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_ADNC_L.pkl'), 'rb') as f:
    SMI32_HC_ADNC_L = pickle.load(f)
f.close()
# SMI32_HC_ADNC_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_ADNC_R.pkl'), 'rb') as f:
    SMI32_HC_ADNC_R = pickle.load(f)
f.close()

# SMI32_Tau_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Age_L.pkl'), 'rb') as f:
    SMI32_Tau_Age_L = pickle.load(f)
f.close()
# SMI32_Tau_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Age_R.pkl'), 'rb') as f:
    SMI32_Tau_Age_R = pickle.load(f)
f.close()
# SMI32_Tau_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Sex_L.pkl'), 'rb') as f:
    SMI32_Tau_Sex_L = pickle.load(f)
f.close()
# SMI32_Tau_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_Sex_R.pkl'), 'rb') as f:
    SMI32_Tau_Sex_R = pickle.load(f)
f.close()
# SMI32_Tau_ADNC_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_ADNC_L.pkl'), 'rb') as f:
    SMI32_Tau_ADNC_L = pickle.load(f)
f.close()
# SMI32_Tau_ADNC_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_ADNC_R.pkl'), 'rb') as f:
    SMI32_Tau_ADNC_R = pickle.load(f)
f.close()

# SMI32_TDP_Age_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Age_L.pkl'), 'rb') as f:
    SMI32_TDP_Age_L = pickle.load(f)
f.close()
# SMI32_TDP_Age_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Age_R.pkl'), 'rb') as f:
    SMI32_TDP_Age_R = pickle.load(f)
f.close()
# SMI32_TDP_Sex_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Sex_L.pkl'), 'rb') as f:
    SMI32_TDP_Sex_L = pickle.load(f)
f.close()
# SMI32_TDP_Sex_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_Sex_R.pkl'), 'rb') as f:
    SMI32_TDP_Sex_R = pickle.load(f)
f.close()
# SMI32_TDP_ADNC_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_ADNC_L.pkl'), 'rb') as f:
    SMI32_TDP_ADNC_L = pickle.load(f)
f.close()
# SMI32_TDP_ADNC_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_ADNC_R.pkl'), 'rb') as f:
    SMI32_TDP_ADNC_R = pickle.load(f)
f.close()

# %%
# SMI32_HC_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3d_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3d_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3v_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3v_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_HC_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_HC_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_HC_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3d_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3d_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_3v_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_3v_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_HC_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_HC_NeuN_5_R = pickle.load(f)
f.close()

# %%
# SMI32_Tau_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3d_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3d_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3v_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3v_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_Tau_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3d_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3d_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_3v_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_3v_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_Tau_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_Tau_NeuN_5_R = pickle.load(f)
f.close()

# %%
# SMI32_TDP_NeuN_1_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_1_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_1_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_2_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_2_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_2_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3d_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3d_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3v_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3v_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_4_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_4_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_4_L = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_5_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_5_L.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_5_L = pickle.load(f)
f.close()

# SMI32_TDP_NeuN_1_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_1_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_1_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_2_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_2_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_2_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3d_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3d_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_3v_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_3v_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_4_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_4_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_4_R = pickle.load(f)
f.close()
# SMI32_TDP_NeuN_5_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_NeuN_5_R.pkl'), 'rb') as f:
    SMI32_TDP_NeuN_5_R = pickle.load(f)
f.close()

# %% [markdown]
# # Calculating W-Score

# %% [markdown]
# ## Format Age Values

# %%
ageHC_L = np.array(SMI32_HC_Age_L).reshape(-1, 1)
ageTau_L = np.array(SMI32_Tau_Age_L).reshape(-1, 1)
ageTDP_L = np.array(SMI32_TDP_Age_L).reshape(-1, 1)

ageHC_R = np.array(SMI32_HC_Age_R).reshape(-1, 1)
ageTau_R = np.array(SMI32_Tau_Age_R).reshape(-1, 1)
ageTDP_R = np.array(SMI32_TDP_Age_R).reshape(-1, 1)

# %% [markdown]
# ## Format Sex Values

# %%
sexHC_L = np.array(SMI32_HC_Sex_L).reshape(-1, 1)
sexTau_L = np.array(SMI32_Tau_Sex_L).reshape(-1, 1)
sexTDP_L = np.array(SMI32_TDP_Sex_L).reshape(-1, 1)

sexHC_R = np.array(SMI32_HC_Sex_R).reshape(-1, 1)
sexTau_R = np.array(SMI32_Tau_Sex_R).reshape(-1, 1)
sexTDP_R = np.array(SMI32_TDP_Sex_R).reshape(-1, 1)

# Convert Male --> 0 / Female --> 1
sexHC_L = np.array(sb.sexToBinary(sexHC_L)).reshape((-1, 1)) 
sexTau_L = np.array(sb.sexToBinary(sexTau_L)).reshape((-1, 1)) 
sexTDP_L = np.array(sb.sexToBinary(sexTDP_L)).reshape((-1, 1)) 

sexHC_R = np.array(sb.sexToBinary(sexHC_R)).reshape((-1, 1)) 
sexTau_R = np.array(sb.sexToBinary(sexTau_R)).reshape((-1, 1)) 
sexTDP_R = np.array(sb.sexToBinary(sexTDP_R)).reshape((-1, 1))

# %% [markdown]
# ## Format L1-6 values

# %%
SMI32_HC_NeuN_1_L = np.array(SMI32_HC_NeuN_1_L).reshape(-1, 1)
SMI32_HC_NeuN_2_L = np.array(SMI32_HC_NeuN_2_L).reshape(-1, 1)
SMI32_HC_NeuN_3d_L = np.array(SMI32_HC_NeuN_3d_L).reshape(-1, 1)
SMI32_HC_NeuN_3v_L = np.array(SMI32_HC_NeuN_3v_L).reshape(-1, 1)
SMI32_HC_NeuN_4_L = np.array(SMI32_HC_NeuN_4_L).reshape(-1, 1)
SMI32_HC_NeuN_5_L = np.array(SMI32_HC_NeuN_5_L).reshape(-1, 1)
SMI32_HC_NeuN_1_R = np.array(SMI32_HC_NeuN_1_R).reshape(-1, 1)
SMI32_HC_NeuN_2_R = np.array(SMI32_HC_NeuN_2_R).reshape(-1, 1)
SMI32_HC_NeuN_3d_R = np.array(SMI32_HC_NeuN_3d_R).reshape(-1, 1)
SMI32_HC_NeuN_3v_R = np.array(SMI32_HC_NeuN_3v_R).reshape(-1, 1)
SMI32_HC_NeuN_4_R = np.array(SMI32_HC_NeuN_4_R).reshape(-1, 1)
SMI32_HC_NeuN_5_R = np.array(SMI32_HC_NeuN_5_R).reshape(-1, 1)

SMI32_Tau_NeuN_1_L = np.array(SMI32_Tau_NeuN_1_L).reshape(-1, 1)
SMI32_Tau_NeuN_2_L = np.array(SMI32_Tau_NeuN_2_L).reshape(-1, 1)
SMI32_Tau_NeuN_3d_L = np.array(SMI32_Tau_NeuN_3d_L).reshape(-1, 1)
SMI32_Tau_NeuN_3v_L = np.array(SMI32_Tau_NeuN_3v_L).reshape(-1, 1)
SMI32_Tau_NeuN_4_L = np.array(SMI32_Tau_NeuN_4_L).reshape(-1, 1)
SMI32_Tau_NeuN_5_L = np.array(SMI32_Tau_NeuN_5_L).reshape(-1, 1)
SMI32_Tau_NeuN_1_R = np.array(SMI32_Tau_NeuN_1_R).reshape(-1, 1)
SMI32_Tau_NeuN_2_R = np.array(SMI32_Tau_NeuN_2_R).reshape(-1, 1)
SMI32_Tau_NeuN_3d_R = np.array(SMI32_Tau_NeuN_3d_R).reshape(-1, 1)
SMI32_Tau_NeuN_3v_R = np.array(SMI32_Tau_NeuN_3v_R).reshape(-1, 1)
SMI32_Tau_NeuN_4_R = np.array(SMI32_Tau_NeuN_4_R).reshape(-1, 1)
SMI32_Tau_NeuN_5_R = np.array(SMI32_Tau_NeuN_5_R).reshape(-1, 1)

SMI32_TDP_NeuN_1_L = np.array(SMI32_TDP_NeuN_1_L).reshape(-1, 1)
SMI32_TDP_NeuN_2_L = np.array(SMI32_TDP_NeuN_2_L).reshape(-1, 1)
SMI32_TDP_NeuN_3d_L = np.array(SMI32_TDP_NeuN_3d_L).reshape(-1, 1)
SMI32_TDP_NeuN_3v_L = np.array(SMI32_TDP_NeuN_3v_L).reshape(-1, 1)
SMI32_TDP_NeuN_4_L = np.array(SMI32_TDP_NeuN_4_L).reshape(-1, 1)
SMI32_TDP_NeuN_5_L = np.array(SMI32_TDP_NeuN_5_L).reshape(-1, 1)
SMI32_TDP_NeuN_1_R = np.array(SMI32_TDP_NeuN_1_R).reshape(-1, 1)
SMI32_TDP_NeuN_2_R = np.array(SMI32_TDP_NeuN_2_R).reshape(-1, 1)
SMI32_TDP_NeuN_3d_R = np.array(SMI32_TDP_NeuN_3d_R).reshape(-1, 1)
SMI32_TDP_NeuN_3v_R = np.array(SMI32_TDP_NeuN_3v_R).reshape(-1, 1)
SMI32_TDP_NeuN_4_R = np.array(SMI32_TDP_NeuN_4_R).reshape(-1, 1)
SMI32_TDP_NeuN_5_R = np.array(SMI32_TDP_NeuN_5_R).reshape(-1, 1)

# %% [markdown]
# ## Format ADNC values

# %%
ADNCHC_L = np.array(SMI32_HC_ADNC_L).reshape(-1, 1)
ADNCTau_L = np.array(SMI32_Tau_ADNC_L).reshape(-1, 1)
ADNCTDP_L = np.array(SMI32_TDP_ADNC_L).reshape(-1, 1)

ADNCHC_R = np.array(SMI32_HC_ADNC_R).reshape(-1, 1)
ADNCTau_R = np.array(SMI32_Tau_ADNC_R).reshape(-1, 1)
ADNCTDP_R = np.array(SMI32_TDP_ADNC_R).reshape(-1, 1)

# Convert Male --> 0 / Female --> 1
ADNCHC_L = np.array(sb.ADNCToBinary(ADNCHC_L)).reshape((-1, 1)) 
ADNCTau_L = np.array(sb.ADNCToBinary(ADNCTau_L)).reshape((-1, 1)) 
ADNCTDP_L = np.array(sb.ADNCToBinary(ADNCTDP_L)).reshape((-1, 1)) 

ADNCHC_R = np.array(sb.ADNCToBinary(ADNCHC_R)).reshape((-1, 1)) 
ADNCTau_R = np.array(sb.ADNCToBinary(ADNCTau_R)).reshape((-1, 1)) 
ADNCTDP_R = np.array(sb.ADNCToBinary(ADNCTDP_R)).reshape((-1, 1))

# %% [markdown]
# ## Stack Age, Sex Values

# %%
# # Stack the Age and Sex features into 2D array
# hcCov_L_CT1 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_1_L, ADNCHC_L), axis=1) 
# hcCov_L_CT2 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_2_L, ADNCHC_L), axis=1) 
# hcCov_L_CT3d = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_3d_L, ADNCHC_L), axis=1) 
# hcCov_L_CT3v = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_3v_L, ADNCHC_L), axis=1) 
# hcCov_L_CT4 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_4_L, ADNCHC_L), axis=1) 
# hcCov_L_CT5 = np.concatenate((ageHC_L, sexHC_L, SMI32_HC_NeuN_5_L, ADNCHC_L), axis=1) 

# tauCov_L_CT1 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_1_L, ADNCTau_L), axis=1)  
# tauCov_L_CT2 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_2_L, ADNCTau_L), axis=1)  
# tauCov_L_CT3d = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_3d_L, ADNCTau_L), axis=1) 
# tauCov_L_CT3v = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_3v_L, ADNCTau_L), axis=1)  
# tauCov_L_CT4 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_4_L, ADNCTau_L), axis=1)  
# tauCov_L_CT5 = np.concatenate((ageTau_L, sexTau_L, SMI32_Tau_NeuN_5_L, ADNCTau_L), axis=1)  

# tdpCov_L_CT1 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_1_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT2 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_2_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT3d = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_3d_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT3v = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_3v_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT4 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_4_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT5 = np.concatenate((ageTDP_L, sexTDP_L, SMI32_TDP_NeuN_5_L, ADNCTDP_L), axis=1)

# # Stack the Age and Sex features into 2D array
# hcCov_R_CT1 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_1_R, ADNCHC_R), axis=1) 
# hcCov_R_CT2 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_2_R, ADNCHC_R), axis=1) 
# hcCov_R_CT3d = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_3d_R, ADNCHC_R), axis=1) 
# hcCov_R_CT3v = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_3v_R, ADNCHC_R), axis=1) 
# hcCov_R_CT4 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_4_R, ADNCHC_R), axis=1) 
# hcCov_R_CT5 = np.concatenate((ageHC_R, sexHC_R, SMI32_HC_NeuN_5_R, ADNCHC_R), axis=1) 

# tauCov_R_CT1 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_1_R, ADNCTau_R), axis=1)
# tauCov_R_CT2 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_2_R, ADNCTau_R), axis=1)
# tauCov_R_CT3d = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_3d_R, ADNCTau_R), axis=1)
# tauCov_R_CT3v = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_3v_R, ADNCTau_R), axis=1)
# tauCov_R_CT4 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_4_R, ADNCTau_R), axis=1)
# tauCov_R_CT5 = np.concatenate((ageTau_R, sexTau_R, SMI32_Tau_NeuN_5_R, ADNCTau_R), axis=1)

# tdpCov_R_CT1 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_1_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT2 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_2_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT3d = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_3d_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT3v = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_3v_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT4 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_4_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT5 = np.concatenate((ageTDP_R, sexTDP_R, SMI32_TDP_NeuN_5_R, ADNCTDP_R), axis=1)

# Stack the Age and Sex features into 2D array
hcCov_L_CT1 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT2 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT3d = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT3v = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT4 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT5 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 

tauCov_L_CT1 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT2 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT3d = np.concatenate((ageTau_L, sexTau_L ), axis=1) 
tauCov_L_CT3v = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT4 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT5 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  

tdpCov_L_CT1 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT2 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT3d = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT3v = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT4 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT5 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)

# Stack the Age and Sex features into 2D array
hcCov_R_CT1 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT2 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT3d = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT3v = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT4 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT5 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 

tauCov_R_CT1 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT2 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT3d = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT3v = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT4 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT5 = np.concatenate((ageTau_R, sexTau_R ), axis=1)

tdpCov_R_CT1 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT2 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT3d = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT3v = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT4 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT5 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)

# %% [markdown]
# ## Divide HC, Tau, TDP into Cortical Types

# %%
SMI32_HC_L_CT1 = SMI32_HC_L[:, [0, 0+6]]
SMI32_HC_L_CT2 = SMI32_HC_L[:, [1, 1+6]]
SMI32_HC_L_CT3d = SMI32_HC_L[:, [2, 2+6]]
SMI32_HC_L_CT3v = SMI32_HC_L[:, [3, 3+6]]
SMI32_HC_L_CT4 = SMI32_HC_L[:, [4, 4+6]]
SMI32_HC_L_CT5 = SMI32_HC_L[:, [5, 5+6]]

SMI32_Tau_L_CT1 = SMI32_Tau_L[:, [0, 0+6]]
SMI32_Tau_L_CT2 = SMI32_Tau_L[:, [1, 1+6]]
SMI32_Tau_L_CT3d = SMI32_Tau_L[:, [2, 2+6]]
SMI32_Tau_L_CT3v = SMI32_Tau_L[:, [3, 3+6]]
SMI32_Tau_L_CT4 = SMI32_Tau_L[:, [4, 4+6]]
SMI32_Tau_L_CT5 = SMI32_Tau_L[:, [5, 5+6]]

SMI32_TDP_L_CT1 = SMI32_TDP_L[:, [0, 0+6]]
SMI32_TDP_L_CT2 = SMI32_TDP_L[:, [1, 1+6]]
SMI32_TDP_L_CT3d = SMI32_TDP_L[:, [2, 2+6]]
SMI32_TDP_L_CT3v = SMI32_TDP_L[:, [3, 3+6]]
SMI32_TDP_L_CT4 = SMI32_TDP_L[:, [4, 4+6]]
SMI32_TDP_L_CT5 = SMI32_TDP_L[:, [5, 5+6]]

# %%
SMI32_HC_R_CT1 = SMI32_HC_R[:, [0, 0+6]]
SMI32_HC_R_CT2 = SMI32_HC_R[:, [1, 1+6]]
SMI32_HC_R_CT3d = SMI32_HC_R[:, [2, 2+6]]
SMI32_HC_R_CT3v = SMI32_HC_R[:, [3, 3+6]]
SMI32_HC_R_CT4 = SMI32_HC_R[:, [4, 4+6]]
SMI32_HC_R_CT5 = SMI32_HC_R[:, [5, 5+6]]

SMI32_Tau_R_CT1 = SMI32_Tau_R[:, [0, 0+6]]
SMI32_Tau_R_CT2 = SMI32_Tau_R[:, [1, 1+6]]
SMI32_Tau_R_CT3d = SMI32_Tau_R[:, [2, 2+6]]
SMI32_Tau_R_CT3v = SMI32_Tau_R[:, [3, 3+6]]
SMI32_Tau_R_CT4 = SMI32_Tau_R[:, [4, 4+6]]
SMI32_Tau_R_CT5 = SMI32_Tau_R[:, [5, 5+6]]

SMI32_TDP_R_CT1 = SMI32_TDP_R[:, [0, 0+6]]
SMI32_TDP_R_CT2 = SMI32_TDP_R[:, [1, 1+6]]
SMI32_TDP_R_CT3d = SMI32_TDP_R[:, [2, 2+6]]
SMI32_TDP_R_CT3v = SMI32_TDP_R[:, [3, 3+6]]
SMI32_TDP_R_CT4 = SMI32_TDP_R[:, [4, 4+6]]
SMI32_TDP_R_CT5 = SMI32_TDP_R[:, [5, 5+6]]

# %% [markdown]
# ## Number of regions we are analyzing (N = 10)

# %%
#N = SMI32_HC_L.shape[1]
N=2

# %% [markdown]
# ## Calculate the W-Scores

# %%
# L
## CT1
SMI32_HC_w_L_CT1, SMI32_Tau_w_L_CT1, SMI32_TDP_w_L_CT1 = wScore.generateWScore(hcCov_L_CT1, tauCov_L_CT1, tdpCov_L_CT1, 
                                                                            N, 
                                                                            SMI32_HC_L_CT1, 
                                                                            SMI32_Tau_L_CT1,  
                                                                            SMI32_TDP_L_CT1)
## CT2
SMI32_HC_w_L_CT2, SMI32_Tau_w_L_CT2, SMI32_TDP_w_L_CT2 = wScore.generateWScore(hcCov_L_CT2, tauCov_L_CT2, tdpCov_L_CT2, 
                                                                            N, 
                                                                            SMI32_HC_L_CT2, 
                                                                            SMI32_Tau_L_CT2,  
                                                                            SMI32_TDP_L_CT2)
## CT3d
SMI32_HC_w_L_CT3d, SMI32_Tau_w_L_CT3d, SMI32_TDP_w_L_CT3d = wScore.generateWScore(hcCov_L_CT3d, tauCov_L_CT3d, tdpCov_L_CT3d, 
                                                                            N, 
                                                                            SMI32_HC_L_CT3d, 
                                                                            SMI32_Tau_L_CT3d,  
                                                                            SMI32_TDP_L_CT3d)

## CT3v
SMI32_HC_w_L_CT3v, SMI32_Tau_w_L_CT3v, SMI32_TDP_w_L_CT3v = wScore.generateWScore(hcCov_L_CT3v, tauCov_L_CT3v, tdpCov_L_CT3v, 
                                                                            N, 
                                                                            SMI32_HC_L_CT3v, 
                                                                            SMI32_Tau_L_CT3v,  
                                                                            SMI32_TDP_L_CT3v)
## CT4
SMI32_HC_w_L_CT4, SMI32_Tau_w_L_CT4, SMI32_TDP_w_L_CT4 = wScore.generateWScore(hcCov_L_CT4, tauCov_L_CT4, tdpCov_L_CT4, 
                                                                            N, 
                                                                            SMI32_HC_L_CT4, 
                                                                            SMI32_Tau_L_CT4,  
                                                                            SMI32_TDP_L_CT4)
## CT5
SMI32_HC_w_L_CT5, SMI32_Tau_w_L_CT5, SMI32_TDP_w_L_CT5 = wScore.generateWScore(hcCov_L_CT5, tauCov_L_CT5, tdpCov_L_CT5, 
                                                                            N, 
                                                                            SMI32_HC_L_CT5, 
                                                                            SMI32_Tau_L_CT5,  
                                                                            SMI32_TDP_L_CT5)

# %%
SMI32_HC_w_L = np.zeros(SMI32_HC_L.shape)
SMI32_Tau_w_L = np.zeros(SMI32_Tau_L.shape)
SMI32_TDP_w_L = np.zeros(SMI32_TDP_L.shape)

for i in range(6):
    if i == 0:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT1
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT1
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT1
        
    elif i == 1:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT2
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT2
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT2
        
    elif i == 2:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT3d
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT3d
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT3d

    elif i == 3:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT3v
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT3v
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT3v
        
    elif i == 4:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT4
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT4
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT4
        
    else:
        SMI32_HC_w_L[:, [i, i+6]] = SMI32_HC_w_L_CT5
        SMI32_Tau_w_L[:, [i, i+6]] = SMI32_Tau_w_L_CT5
        SMI32_TDP_w_L[:, [i, i+6]] = SMI32_TDP_w_L_CT5

# %%
# R
## CT1
SMI32_HC_w_R_CT1, SMI32_Tau_w_R_CT1, SMI32_TDP_w_R_CT1 = wScore.generateWScore(hcCov_R_CT1, tauCov_R_CT1, tdpCov_R_CT1, 
                                                                            N, 
                                                                            SMI32_HC_R_CT1, 
                                                                            SMI32_Tau_R_CT1,  
                                                                            SMI32_TDP_R_CT1)
## CT2
SMI32_HC_w_R_CT2, SMI32_Tau_w_R_CT2, SMI32_TDP_w_R_CT2 = wScore.generateWScore(hcCov_R_CT2, tauCov_R_CT2, tdpCov_R_CT2, 
                                                                            N, 
                                                                            SMI32_HC_R_CT2, 
                                                                            SMI32_Tau_R_CT2,  
                                                                            SMI32_TDP_R_CT2)
## CT3d
SMI32_HC_w_R_CT3d, SMI32_Tau_w_R_CT3d, SMI32_TDP_w_R_CT3d = wScore.generateWScore(hcCov_R_CT3d, tauCov_R_CT3d, tdpCov_R_CT3d, 
                                                                            N, 
                                                                            SMI32_HC_R_CT3d, 
                                                                            SMI32_Tau_R_CT3d,  
                                                                            SMI32_TDP_R_CT3d)

## CT3v
SMI32_HC_w_R_CT3v, SMI32_Tau_w_R_CT3v, SMI32_TDP_w_R_CT3v = wScore.generateWScore(hcCov_R_CT3v, tauCov_R_CT3v, tdpCov_R_CT3v, 
                                                                            N, 
                                                                            SMI32_HC_R_CT3v, 
                                                                            SMI32_Tau_R_CT3v,  
                                                                            SMI32_TDP_R_CT3v)
## CT4
SMI32_HC_w_R_CT4, SMI32_Tau_w_R_CT4, SMI32_TDP_w_R_CT4 = wScore.generateWScore(hcCov_R_CT4, tauCov_R_CT4, tdpCov_R_CT4, 
                                                                            N, 
                                                                            SMI32_HC_R_CT4, 
                                                                            SMI32_Tau_R_CT4,  
                                                                            SMI32_TDP_R_CT4)
## CT5
SMI32_HC_w_R_CT5, SMI32_Tau_w_R_CT5, SMI32_TDP_w_R_CT5 = wScore.generateWScore(hcCov_R_CT5, tauCov_R_CT5, tdpCov_R_CT5, 
                                                                            N, 
                                                                            SMI32_HC_R_CT5, 
                                                                            SMI32_Tau_R_CT5,  
                                                                            SMI32_TDP_R_CT5)

# %%
SMI32_HC_w_R = np.zeros(SMI32_HC_R.shape)
SMI32_Tau_w_R = np.zeros(SMI32_Tau_R.shape)
SMI32_TDP_w_R = np.zeros(SMI32_TDP_R.shape)

for i in range(6):
    if i == 0:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT1
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT1
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT1
        
    elif i == 1:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT2
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT2
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT2
        
    elif i == 2:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT3d
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT3d
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT3d

    elif i == 3:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT3v
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT3v
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT3v
        
    elif i == 4:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT4
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT4
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT4
        
    else:
        SMI32_HC_w_R[:, [i, i+6]] = SMI32_HC_w_R_CT5
        SMI32_Tau_w_R[:, [i, i+6]] = SMI32_Tau_w_R_CT5
        SMI32_TDP_w_R[:, [i, i+6]] = SMI32_TDP_w_R_CT5

# %% [markdown]
# # Show Data Distribution Before and After W-Score

# %% [markdown]
# ## Before

# %%
bp.drawthicknessboxplot(SMI32_HC_L, SMI32_Tau_L, SMI32_TDP_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32).png")

# %%
bp.drawthicknessboxplot(SMI32_HC_R, SMI32_Tau_R, SMI32_TDP_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32).png")

# %% [markdown]
# ## After

# %%
SMI32_HC_w_L
# Out:
# array([[-0.84807013, -1.013175  , -1.60871689, -1.08246005, -0.74125707,
#                 nan, -1.23922328, -2.27675248, -2.22025899, -1.52588925,
#         -2.09924696,         nan],
#        [        nan,         nan,         nan, -0.43091403, -0.42718352,
#         -0.89922319,         nan,         nan,         nan,  0.86146055,
#          0.30733692, -0.39931752],
#        [        nan,  0.72855699,  0.05888748,  1.32313939,  1.2634282 ,
#                 nan,         nan,  0.30365704, -0.32391206,  0.16456124,
#          1.02951544,         nan],
#        [ 0.09566486,  0.2205422 ,  1.09559275,  0.63257377,  0.41862383,
#                 nan,  0.78513134,  1.07091328,  1.3569049 ,  1.38932082,
#          1.08828954,         nan],
#        [ 0.82761805,  0.37052032,         nan,         nan,         nan,
#                 nan, -0.09134118, -0.14606961,         nan,         nan,
#                 nan,         nan],
# ...

# %%
bp.drawthicknessboxplot(SMI32_HC_w_L, SMI32_Tau_w_L, SMI32_TDP_w_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32)_WScore.png")

# %%
bp.drawthicknessboxplot(SMI32_HC_w_R, SMI32_Tau_w_R, SMI32_TDP_w_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(SMI32)_WScore.png")

# %% [markdown]
# # Saving

# %%
# SMI32_HC_w_L
with open(os.path.join(layer_dataDir, 'SMI32_HC_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_HC_w_L, f)
f.close()

# SMI32_Tau_w_L
with open(os.path.join(layer_dataDir, 'SMI32_Tau_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_Tau_w_L, f)
f.close()

# SMI32_TDP_w_L
with open(os.path.join(layer_dataDir, 'SMI32_TDP_w_L.pkl'), 'wb') as f:
    pickle.dump(SMI32_TDP_w_L, f)
f.close()

# %%
# SMI32_HC_w_R
with open(os.path.join(layer_dataDir, 'SMI32_HC_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_HC_w_R, f)
f.close()

# SMI32_Tau_w_R
with open(os.path.join(layer_dataDir, 'SMI32_Tau_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_Tau_w_R, f)
f.close()

# SMI32_TDP_w_R
with open(os.path.join(layer_dataDir, 'SMI32_TDP_w_R.pkl'), 'wb') as f:
    pickle.dump(SMI32_TDP_w_R, f)
f.close()

# %%
data = SMI32_HC_L

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score):")
print(nan_count_per_column)

data = SMI32_HC_w_L
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score):")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column (BEFORE W-Score):
# [5 2 8 5 4 6 5 2 8 5 4 6]
# Number of NaN values in each column (AFTER W-Score):
# [5 2 8 5 4 6 5 2 8 5 4 6]

# %%
pd.DataFrame(SMI32_HC_L)
# Out:
#           0         1         2         3         4         5         6   \
# 0  -5.869131 -5.744920 -4.548573 -5.413872 -4.899720       NaN -4.073712
# 1        NaN       NaN       NaN -5.387686 -4.973551 -4.172748       NaN
# 2        NaN -4.412542 -3.775226 -4.355858 -3.869681       NaN       NaN
# 3  -4.852664 -4.693026 -3.281627 -4.190608 -4.036916       NaN -2.946921
# 4  -4.436848 -4.449497       NaN       NaN       NaN       NaN -3.673699
# 5  -5.666501 -3.767018 -3.096435       NaN -4.309830       NaN -3.446930
# 6  -6.918591 -7.071622       NaN -7.175581 -6.849041 -4.791063 -4.377048
# 7  -3.688273 -4.263021 -3.588690       NaN       NaN -3.308420 -2.900213
# 8  -5.634161 -5.213589 -3.996230 -4.311577 -3.398889 -3.423748 -2.900153
# 9  -5.438886 -4.111186       NaN       NaN       NaN -4.139751 -4.068231
# 10 -2.637379 -3.265025       NaN -3.280559 -3.157080 -4.010533 -2.735615
# 11       NaN       NaN       NaN -5.069504 -4.191615 -4.030137       NaN
# ...

# %%
pd.DataFrame(SMI32_HC_w_L)
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.848070 -1.013175 -1.608717 -1.082460 -0.741257       NaN -1.239223
# 1        NaN       NaN       NaN -0.430914 -0.427184 -0.899223       NaN
# 2        NaN  0.728557  0.058887  1.323139  1.263428       NaN       NaN
# 3   0.095665  0.220542  1.095593  0.632574  0.418624       NaN  0.785131
# 4   0.827618  0.370520       NaN       NaN       NaN       NaN -0.091341
# 5   0.062351  1.499221  1.703897       NaN  0.444740       NaN  0.236707
# 6  -1.031711 -2.316911       NaN -2.019315 -2.762096 -1.562819 -1.448741
# 7   1.347830  0.874082  0.454237       NaN       NaN  1.061788  0.832973
# 8  -0.010277 -0.286918 -0.225169  1.227521  1.359338  1.115025  1.240671
# 9  -0.136938  0.737468       NaN       NaN       NaN -1.036309 -0.792930
# 10  2.498328  1.759732       NaN  1.443358  0.857756 -0.688303  1.593988
# 11       NaN       NaN       NaN -0.449937 -0.119660 -0.473426       NaN
# ...
