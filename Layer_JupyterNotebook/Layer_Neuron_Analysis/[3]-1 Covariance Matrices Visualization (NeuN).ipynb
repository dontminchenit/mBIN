# %% [markdown]
# # Import

# %%
import sys
import os
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Covariance Matrices

# %%
# cov_NeuN_dict
with open(os.path.join(layer_CalData, 'cov_NeuN_dict.pkl'), 'rb') as f:
    cov_NeuN_dict = pickle.load(f)
f.close()

# %%
# cov_NeuN_dict_w_agesex
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_w_agesex.pkl'), 'rb') as f:
    cov_NeuN_dict_w_agesex = pickle.load(f)
f.close()


# cov_NeuN_dict_w_agesexNeuNADNC
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_w_agesexNeuNADNC.pkl'), 'rb') as f:
    cov_NeuN_dict_w_agesexNeuNADNC = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Layer Neuron Labels (NeuN)

# %%
# NeuN_Labels
with open(os.path.join(layer_dataDir, 'NeuN_Labels.pkl'), 'rb') as f:
    NeuN_Labels = pickle.load(f)
f.close()

# %%
NeuN_Labels = ['L23_1(Cingulate)', 'L23_2(Cingulate)', 'L23_3d(Paracingulate)', 'L23_3v(Paracingulate)', 'L23_4(Rectus)', 'L23_5(Middle Frontal)', 
               'L56_1(Cingulate)', 'L56_2(Cingulate)', 'L56_3d(Paracingulate)', 'L56_3v(Paracingulate)', 'L56_4(Rectus)', 'L56_5(Middle Frontal)']

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Divide into Long, Short Paths

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC (covMat) - Long(Canonical)', subpath = 'canonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC (covMat) - Long(Non-Canonical)', subpath = 'noncanonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC (covMat) - Short', subpath = 'short', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau (covMat) - Long(Canonical)', subpath = 'canonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau (covMat) - Long(Non-Canonical)', subpath = 'noncanonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau (covMat) - Short', subpath = 'short', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP (covMat) - Long(Canonical)', subpath='canonical',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP (covMat) - Long(Non-Canonical)', subpath='noncanonical',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_NeuN_dict['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP (covMat) - Short', subpath='short',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Stratification

# %%
maxval = 0.0
minval = -0.2
viz.drawCovMatrixStrat(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, f'NeuN_HC (covMat) {maxval} ~ {minval}', minval=minval, maxval=maxval, outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) W Score (age, sex)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesex['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) W Score (age, sex, NeuN, ADNC)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w_agesexNeuNADNC['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)
