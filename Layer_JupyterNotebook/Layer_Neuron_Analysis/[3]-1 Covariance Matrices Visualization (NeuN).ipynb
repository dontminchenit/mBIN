# %% [markdown]
# # Import

# %%
import sys
import os
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Covariance Matrices

# %%
# cov_NeuN_dict
with open(os.path.join(layer_CalData, 'cov_NeuN_dict.pkl'), 'rb') as f:
    cov_NeuN_dict = pickle.load(f)
f.close()

# %%
# cov_NeuN_dict_w
with open(os.path.join(layer_CalData, 'cov_NeuN_dict_w.pkl'), 'rb') as f:
    cov_NeuN_dict_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Layer Neuron Labels (NeuN)

# %%
# NeuN_Labels
with open(os.path.join(layer_dataDir, 'NeuN_Labels.pkl'), 'rb') as f:
    NeuN_Labels = pickle.load(f)
f.close()

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (NeuN) W Score

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['HC'], NeuN_Labels, NeuN_Labels, 'NeuN_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TAU'], NeuN_Labels, NeuN_Labels, 'NeuN_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TDP'], NeuN_Labels, NeuN_Labels, 'NeuN_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TAU_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TAU_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TDP_lt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TDP_gt_HC'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TAU_gt_TDP'], NeuN_Labels, NeuN_Labels, 'NeuN Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_NeuN_dict_w['TDP_gt_TAU'], NeuN_Labels, NeuN_Labels, 'NeuN TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)
