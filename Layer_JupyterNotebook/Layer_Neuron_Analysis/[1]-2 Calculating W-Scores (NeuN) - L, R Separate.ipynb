# %% [markdown]
# # Imports

# %%
import sys
import os
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import sexToBinary as sb
import wScore
import boxPlot as bp

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Formatted Layer Neuron Data (NeuN)

# %% [markdown]
# ### HC

# %%
# NeuN_HC_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_L.pkl'), 'rb') as f:
    NeuN_HC_L = pickle.load(f)
f.close()

# NeuN_HC_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_R.pkl'), 'rb') as f:
    NeuN_HC_R = pickle.load(f)
f.close()

# %%
NeuN_HC_L.shape
# Out:
# (18, 12)

# %%
NeuN_HC_R.shape
# Out:
# (14, 12)

# %% [markdown]
# ### Tau

# %%
# NeuN_Tau_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_L.pkl'), 'rb') as f:
    NeuN_Tau_L = pickle.load(f)
f.close()

# NeuN_Tau_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_R.pkl'), 'rb') as f:
    NeuN_Tau_R = pickle.load(f)
f.close()

# %%
NeuN_Tau_L.shape
# Out:
# (16, 12)

# %%
NeuN_Tau_R.shape
# Out:
# (16, 12)

# %% [markdown]
# ### TDP

# %%
# NeuN_TDP_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_L.pkl'), 'rb') as f:
    NeuN_TDP_L = pickle.load(f)
f.close()

# NeuN_TDP_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_R.pkl'), 'rb') as f:
    NeuN_TDP_R = pickle.load(f)
f.close()

# %%
NeuN_TDP_L.shape
# Out:
# (33, 12)

# %%
NeuN_TDP_R.shape
# Out:
# (28, 12)

# %% [markdown]
# ## Loading Age, Sex, L1-6_NeuN, ADNC values

# %%
# NeuN_HC_Age_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_Age_L.pkl'), 'rb') as f:
    NeuN_HC_Age_L = pickle.load(f)
f.close()
# NeuN_HC_Age_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_Age_R.pkl'), 'rb') as f:
    NeuN_HC_Age_R = pickle.load(f)
f.close()
# NeuN_HC_Sex_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_Sex_L.pkl'), 'rb') as f:
    NeuN_HC_Sex_L = pickle.load(f)
f.close()
# NeuN_HC_Sex_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_Sex_R.pkl'), 'rb') as f:
    NeuN_HC_Sex_R = pickle.load(f)
f.close()
# NeuN_HC_ADNC_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_ADNC_L.pkl'), 'rb') as f:
    NeuN_HC_ADNC_L = pickle.load(f)
f.close()
# NeuN_HC_ADNC_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_ADNC_R.pkl'), 'rb') as f:
    NeuN_HC_ADNC_R = pickle.load(f)
f.close()

# NeuN_Tau_Age_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_Age_L.pkl'), 'rb') as f:
    NeuN_Tau_Age_L = pickle.load(f)
f.close()
# NeuN_Tau_Age_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_Age_R.pkl'), 'rb') as f:
    NeuN_Tau_Age_R = pickle.load(f)
f.close()
# NeuN_Tau_Sex_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_Sex_L.pkl'), 'rb') as f:
    NeuN_Tau_Sex_L = pickle.load(f)
f.close()
# NeuN_Tau_Sex_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_Sex_R.pkl'), 'rb') as f:
    NeuN_Tau_Sex_R = pickle.load(f)
f.close()
# NeuN_Tau_ADNC_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_ADNC_L.pkl'), 'rb') as f:
    NeuN_Tau_ADNC_L = pickle.load(f)
f.close()
# NeuN_Tau_ADNC_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_ADNC_R.pkl'), 'rb') as f:
    NeuN_Tau_ADNC_R = pickle.load(f)
f.close()

# NeuN_TDP_Age_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_Age_L.pkl'), 'rb') as f:
    NeuN_TDP_Age_L = pickle.load(f)
f.close()
# NeuN_TDP_Age_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_Age_R.pkl'), 'rb') as f:
    NeuN_TDP_Age_R = pickle.load(f)
f.close()
# NeuN_TDP_Sex_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_Sex_L.pkl'), 'rb') as f:
    NeuN_TDP_Sex_L = pickle.load(f)
f.close()
# NeuN_TDP_Sex_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_Sex_R.pkl'), 'rb') as f:
    NeuN_TDP_Sex_R = pickle.load(f)
f.close()
# NeuN_TDP_ADNC_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_ADNC_L.pkl'), 'rb') as f:
    NeuN_TDP_ADNC_L = pickle.load(f)
f.close()
# NeuN_TDP_ADNC_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_ADNC_R.pkl'), 'rb') as f:
    NeuN_TDP_ADNC_R = pickle.load(f)
f.close()

# %%
# NeuN_HC_NeuN_1_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_1_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_1_L = pickle.load(f)
f.close()
# NeuN_HC_NeuN_2_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_2_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_2_L = pickle.load(f)
f.close()
# NeuN_HC_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_3d_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_3d_L = pickle.load(f)
f.close()
# NeuN_HC_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_3v_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_3v_L = pickle.load(f)
f.close()
# NeuN_HC_NeuN_4_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_4_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_4_L = pickle.load(f)
f.close()
# NeuN_HC_NeuN_5_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_5_L.pkl'), 'rb') as f:
    NeuN_HC_NeuN_5_L = pickle.load(f)
f.close()

# NeuN_HC_NeuN_1_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_1_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_1_R = pickle.load(f)
f.close()
# NeuN_HC_NeuN_2_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_2_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_2_R = pickle.load(f)
f.close()
# NeuN_HC_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_3d_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_3d_R = pickle.load(f)
f.close()
# NeuN_HC_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_3v_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_3v_R = pickle.load(f)
f.close()
# NeuN_HC_NeuN_4_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_4_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_4_R = pickle.load(f)
f.close()
# NeuN_HC_NeuN_5_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_NeuN_5_R.pkl'), 'rb') as f:
    NeuN_HC_NeuN_5_R = pickle.load(f)
f.close()

# %%
# NeuN_Tau_NeuN_1_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_1_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_1_L = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_2_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_2_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_2_L = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_3d_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_3d_L = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_3v_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_3v_L = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_4_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_4_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_4_L = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_5_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_5_L.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_5_L = pickle.load(f)
f.close()

# NeuN_Tau_NeuN_1_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_1_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_1_R = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_2_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_2_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_2_R = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_3d_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_3d_R = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_3v_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_3v_R = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_4_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_4_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_4_R = pickle.load(f)
f.close()
# NeuN_Tau_NeuN_5_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_NeuN_5_R.pkl'), 'rb') as f:
    NeuN_Tau_NeuN_5_R = pickle.load(f)
f.close()

# %%
# NeuN_TDP_NeuN_1_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_1_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_1_L = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_2_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_2_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_2_L = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_3d_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_3d_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_3d_L = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_3v_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_3v_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_3v_L = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_4_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_4_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_4_L = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_5_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_5_L.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_5_L = pickle.load(f)
f.close()

# NeuN_TDP_NeuN_1_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_1_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_1_R = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_2_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_2_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_2_R = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_3d_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_3d_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_3d_R = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_3v_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_3v_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_3v_R = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_4_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_4_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_4_R = pickle.load(f)
f.close()
# NeuN_TDP_NeuN_5_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_NeuN_5_R.pkl'), 'rb') as f:
    NeuN_TDP_NeuN_5_R = pickle.load(f)
f.close()

# %% [markdown]
# # Calculating W-Score

# %% [markdown]
# ## Format Age Values

# %%
ageHC_L = np.array(NeuN_HC_Age_L).reshape(-1, 1)
ageTau_L = np.array(NeuN_Tau_Age_L).reshape(-1, 1)
ageTDP_L = np.array(NeuN_TDP_Age_L).reshape(-1, 1)

ageHC_R = np.array(NeuN_HC_Age_R).reshape(-1, 1)
ageTau_R = np.array(NeuN_Tau_Age_R).reshape(-1, 1)
ageTDP_R = np.array(NeuN_TDP_Age_R).reshape(-1, 1)

# %% [markdown]
# ## Format Sex Values

# %%
sexHC_L = np.array(NeuN_HC_Sex_L).reshape(-1, 1)
sexTau_L = np.array(NeuN_Tau_Sex_L).reshape(-1, 1)
sexTDP_L = np.array(NeuN_TDP_Sex_L).reshape(-1, 1)

sexHC_R = np.array(NeuN_HC_Sex_R).reshape(-1, 1)
sexTau_R = np.array(NeuN_Tau_Sex_R).reshape(-1, 1)
sexTDP_R = np.array(NeuN_TDP_Sex_R).reshape(-1, 1)

# Convert Male --> 0 / Female --> 1
sexHC_L = np.array(sb.sexToBinary(sexHC_L)).reshape((-1, 1)) 
sexTau_L = np.array(sb.sexToBinary(sexTau_L)).reshape((-1, 1)) 
sexTDP_L = np.array(sb.sexToBinary(sexTDP_L)).reshape((-1, 1)) 

sexHC_R = np.array(sb.sexToBinary(sexHC_R)).reshape((-1, 1)) 
sexTau_R = np.array(sb.sexToBinary(sexTau_R)).reshape((-1, 1)) 
sexTDP_R = np.array(sb.sexToBinary(sexTDP_R)).reshape((-1, 1))

# %% [markdown]
# ## Format L1-6 values

# %%
NeuN_HC_NeuN_1_L = np.array(NeuN_HC_NeuN_1_L).reshape(-1, 1)
NeuN_HC_NeuN_2_L = np.array(NeuN_HC_NeuN_2_L).reshape(-1, 1)
NeuN_HC_NeuN_3d_L = np.array(NeuN_HC_NeuN_3d_L).reshape(-1, 1)
NeuN_HC_NeuN_3v_L = np.array(NeuN_HC_NeuN_3v_L).reshape(-1, 1)
NeuN_HC_NeuN_4_L = np.array(NeuN_HC_NeuN_4_L).reshape(-1, 1)
NeuN_HC_NeuN_5_L = np.array(NeuN_HC_NeuN_5_L).reshape(-1, 1)
NeuN_HC_NeuN_1_R = np.array(NeuN_HC_NeuN_1_R).reshape(-1, 1)
NeuN_HC_NeuN_2_R = np.array(NeuN_HC_NeuN_2_R).reshape(-1, 1)
NeuN_HC_NeuN_3d_R = np.array(NeuN_HC_NeuN_3d_R).reshape(-1, 1)
NeuN_HC_NeuN_3v_R = np.array(NeuN_HC_NeuN_3v_R).reshape(-1, 1)
NeuN_HC_NeuN_4_R = np.array(NeuN_HC_NeuN_4_R).reshape(-1, 1)
NeuN_HC_NeuN_5_R = np.array(NeuN_HC_NeuN_5_R).reshape(-1, 1)

NeuN_Tau_NeuN_1_L = np.array(NeuN_Tau_NeuN_1_L).reshape(-1, 1)
NeuN_Tau_NeuN_2_L = np.array(NeuN_Tau_NeuN_2_L).reshape(-1, 1)
NeuN_Tau_NeuN_3d_L = np.array(NeuN_Tau_NeuN_3d_L).reshape(-1, 1)
NeuN_Tau_NeuN_3v_L = np.array(NeuN_Tau_NeuN_3v_L).reshape(-1, 1)
NeuN_Tau_NeuN_4_L = np.array(NeuN_Tau_NeuN_4_L).reshape(-1, 1)
NeuN_Tau_NeuN_5_L = np.array(NeuN_Tau_NeuN_5_L).reshape(-1, 1)
NeuN_Tau_NeuN_1_R = np.array(NeuN_Tau_NeuN_1_R).reshape(-1, 1)
NeuN_Tau_NeuN_2_R = np.array(NeuN_Tau_NeuN_2_R).reshape(-1, 1)
NeuN_Tau_NeuN_3d_R = np.array(NeuN_Tau_NeuN_3d_R).reshape(-1, 1)
NeuN_Tau_NeuN_3v_R = np.array(NeuN_Tau_NeuN_3v_R).reshape(-1, 1)
NeuN_Tau_NeuN_4_R = np.array(NeuN_Tau_NeuN_4_R).reshape(-1, 1)
NeuN_Tau_NeuN_5_R = np.array(NeuN_Tau_NeuN_5_R).reshape(-1, 1)

NeuN_TDP_NeuN_1_L = np.array(NeuN_TDP_NeuN_1_L).reshape(-1, 1)
NeuN_TDP_NeuN_2_L = np.array(NeuN_TDP_NeuN_2_L).reshape(-1, 1)
NeuN_TDP_NeuN_3d_L = np.array(NeuN_TDP_NeuN_3d_L).reshape(-1, 1)
NeuN_TDP_NeuN_3v_L = np.array(NeuN_TDP_NeuN_3v_L).reshape(-1, 1)
NeuN_TDP_NeuN_4_L = np.array(NeuN_TDP_NeuN_4_L).reshape(-1, 1)
NeuN_TDP_NeuN_5_L = np.array(NeuN_TDP_NeuN_5_L).reshape(-1, 1)
NeuN_TDP_NeuN_1_R = np.array(NeuN_TDP_NeuN_1_R).reshape(-1, 1)
NeuN_TDP_NeuN_2_R = np.array(NeuN_TDP_NeuN_2_R).reshape(-1, 1)
NeuN_TDP_NeuN_3d_R = np.array(NeuN_TDP_NeuN_3d_R).reshape(-1, 1)
NeuN_TDP_NeuN_3v_R = np.array(NeuN_TDP_NeuN_3v_R).reshape(-1, 1)
NeuN_TDP_NeuN_4_R = np.array(NeuN_TDP_NeuN_4_R).reshape(-1, 1)
NeuN_TDP_NeuN_5_R = np.array(NeuN_TDP_NeuN_5_R).reshape(-1, 1)

# %% [markdown]
# ## Format ADNC values

# %%
ADNCHC_L = np.array(NeuN_HC_ADNC_L).reshape(-1, 1)
ADNCTau_L = np.array(NeuN_Tau_ADNC_L).reshape(-1, 1)
ADNCTDP_L = np.array(NeuN_TDP_ADNC_L).reshape(-1, 1)

ADNCHC_R = np.array(NeuN_HC_ADNC_R).reshape(-1, 1)
ADNCTau_R = np.array(NeuN_Tau_ADNC_R).reshape(-1, 1)
ADNCTDP_R = np.array(NeuN_TDP_ADNC_R).reshape(-1, 1)

# Convert Male --> 0 / Female --> 1
ADNCHC_L = np.array(sb.ADNCToBinary(ADNCHC_L)).reshape((-1, 1)) 
ADNCTau_L = np.array(sb.ADNCToBinary(ADNCTau_L)).reshape((-1, 1)) 
ADNCTDP_L = np.array(sb.ADNCToBinary(ADNCTDP_L)).reshape((-1, 1)) 

ADNCHC_R = np.array(sb.ADNCToBinary(ADNCHC_R)).reshape((-1, 1)) 
ADNCTau_R = np.array(sb.ADNCToBinary(ADNCTau_R)).reshape((-1, 1)) 
ADNCTDP_R = np.array(sb.ADNCToBinary(ADNCTDP_R)).reshape((-1, 1))

# %% [markdown]
# ## Stack Age, Sex Values

# %%
# # Stack the Age and Sex features into 2D array
# hcCov_L_CT1 = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_1_L, ADNCHC_L), axis=1) 
# hcCov_L_CT2 = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_2_L, ADNCHC_L), axis=1) 
# hcCov_L_CT3d = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_3d_L, ADNCHC_L), axis=1) 
# hcCov_L_CT3v = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_3v_L, ADNCHC_L), axis=1) 
# hcCov_L_CT4 = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_4_L, ADNCHC_L), axis=1) 
# hcCov_L_CT5 = np.concatenate((ageHC_L, sexHC_L, NeuN_HC_NeuN_5_L, ADNCHC_L), axis=1) 

# tauCov_L_CT1 = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_1_L, ADNCTau_L), axis=1)  
# tauCov_L_CT2 = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_2_L, ADNCTau_L), axis=1)  
# tauCov_L_CT3d = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_3d_L, ADNCTau_L), axis=1) 
# tauCov_L_CT3v = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_3v_L, ADNCTau_L), axis=1)  
# tauCov_L_CT4 = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_4_L, ADNCTau_L), axis=1)  
# tauCov_L_CT5 = np.concatenate((ageTau_L, sexTau_L, NeuN_Tau_NeuN_5_L, ADNCTau_L), axis=1)  

# tdpCov_L_CT1 = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_1_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT2 = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_2_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT3d = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_3d_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT3v = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_3v_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT4 = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_4_L, ADNCTDP_L), axis=1)
# tdpCov_L_CT5 = np.concatenate((ageTDP_L, sexTDP_L, NeuN_TDP_NeuN_5_L, ADNCTDP_L), axis=1)

# # Stack the Age and Sex features into 2D array
# hcCov_R_CT1 = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_1_R, ADNCHC_R), axis=1) 
# hcCov_R_CT2 = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_2_R, ADNCHC_R), axis=1) 
# hcCov_R_CT3d = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_3d_R, ADNCHC_R), axis=1) 
# hcCov_R_CT3v = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_3v_R, ADNCHC_R), axis=1) 
# hcCov_R_CT4 = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_4_R, ADNCHC_R), axis=1) 
# hcCov_R_CT5 = np.concatenate((ageHC_R, sexHC_R, NeuN_HC_NeuN_5_R, ADNCHC_R), axis=1) 

# tauCov_R_CT1 = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_1_R, ADNCTau_R), axis=1)
# tauCov_R_CT2 = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_2_R, ADNCTau_R), axis=1)
# tauCov_R_CT3d = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_3d_R, ADNCTau_R), axis=1)
# tauCov_R_CT3v = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_3v_R, ADNCTau_R), axis=1)
# tauCov_R_CT4 = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_4_R, ADNCTau_R), axis=1)
# tauCov_R_CT5 = np.concatenate((ageTau_R, sexTau_R, NeuN_Tau_NeuN_5_R, ADNCTau_R), axis=1)

# tdpCov_R_CT1 = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_1_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT2 = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_2_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT3d = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_3d_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT3v = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_3v_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT4 = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_4_R, ADNCTDP_R), axis=1)
# tdpCov_R_CT5 = np.concatenate((ageTDP_R, sexTDP_R, NeuN_TDP_NeuN_5_R, ADNCTDP_R), axis=1)

# Stack the Age and Sex features into 2D array
hcCov_L_CT1 = np.concatenate((ageHC_L, sexHC_L), axis=1) 
hcCov_L_CT2 = np.concatenate((ageHC_L, sexHC_L), axis=1) 
hcCov_L_CT3d = np.concatenate((ageHC_L, sexHC_L), axis=1) 
hcCov_L_CT3v = np.concatenate((ageHC_L, sexHC_L), axis=1) 
hcCov_L_CT4 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 
hcCov_L_CT5 = np.concatenate((ageHC_L, sexHC_L ), axis=1) 

tauCov_L_CT1 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT2 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT3d = np.concatenate((ageTau_L, sexTau_L ), axis=1) 
tauCov_L_CT3v = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT4 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  
tauCov_L_CT5 = np.concatenate((ageTau_L, sexTau_L ), axis=1)  

tdpCov_L_CT1 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT2 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT3d = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT3v = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT4 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)
tdpCov_L_CT5 = np.concatenate((ageTDP_L, sexTDP_L ), axis=1)

# Stack the Age and Sex features into 2D array
hcCov_R_CT1 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT2 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT3d = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT3v = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT4 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 
hcCov_R_CT5 = np.concatenate((ageHC_R, sexHC_R ), axis=1) 

tauCov_R_CT1 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT2 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT3d = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT3v = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT4 = np.concatenate((ageTau_R, sexTau_R ), axis=1)
tauCov_R_CT5 = np.concatenate((ageTau_R, sexTau_R ), axis=1)

tdpCov_R_CT1 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT2 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT3d = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT3v = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT4 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)
tdpCov_R_CT5 = np.concatenate((ageTDP_R, sexTDP_R ), axis=1)

# %% [markdown]
# ## Divide HC, Tau, TDP into Cortical Types

# %%
NeuN_HC_L_CT1 = NeuN_HC_L[:, [0, 0+6]]
NeuN_HC_L_CT2 = NeuN_HC_L[:, [1, 1+6]]
NeuN_HC_L_CT3d = NeuN_HC_L[:, [2, 2+6]]
NeuN_HC_L_CT3v = NeuN_HC_L[:, [3, 3+6]]
NeuN_HC_L_CT4 = NeuN_HC_L[:, [4, 4+6]]
NeuN_HC_L_CT5 = NeuN_HC_L[:, [5, 5+6]]

NeuN_Tau_L_CT1 = NeuN_Tau_L[:, [0, 0+6]]
NeuN_Tau_L_CT2 = NeuN_Tau_L[:, [1, 1+6]]
NeuN_Tau_L_CT3d = NeuN_Tau_L[:, [2, 2+6]]
NeuN_Tau_L_CT3v = NeuN_Tau_L[:, [3, 3+6]]
NeuN_Tau_L_CT4 = NeuN_Tau_L[:, [4, 4+6]]
NeuN_Tau_L_CT5 = NeuN_Tau_L[:, [5, 5+6]]

NeuN_TDP_L_CT1 = NeuN_TDP_L[:, [0, 0+6]]
NeuN_TDP_L_CT2 = NeuN_TDP_L[:, [1, 1+6]]
NeuN_TDP_L_CT3d = NeuN_TDP_L[:, [2, 2+6]]
NeuN_TDP_L_CT3v = NeuN_TDP_L[:, [3, 3+6]]
NeuN_TDP_L_CT4 = NeuN_TDP_L[:, [4, 4+6]]
NeuN_TDP_L_CT5 = NeuN_TDP_L[:, [5, 5+6]]

# %%
NeuN_HC_R_CT1 = NeuN_HC_R[:, [0, 0+6]]
NeuN_HC_R_CT2 = NeuN_HC_R[:, [1, 1+6]]
NeuN_HC_R_CT3d = NeuN_HC_R[:, [2, 2+6]]
NeuN_HC_R_CT3v = NeuN_HC_R[:, [3, 3+6]]
NeuN_HC_R_CT4 = NeuN_HC_R[:, [4, 4+6]]
NeuN_HC_R_CT5 = NeuN_HC_R[:, [5, 5+6]]

NeuN_Tau_R_CT1 = NeuN_Tau_R[:, [0, 0+6]]
NeuN_Tau_R_CT2 = NeuN_Tau_R[:, [1, 1+6]]
NeuN_Tau_R_CT3d = NeuN_Tau_R[:, [2, 2+6]]
NeuN_Tau_R_CT3v = NeuN_Tau_R[:, [3, 3+6]]
NeuN_Tau_R_CT4 = NeuN_Tau_R[:, [4, 4+6]]
NeuN_Tau_R_CT5 = NeuN_Tau_R[:, [5, 5+6]]

NeuN_TDP_R_CT1 = NeuN_TDP_R[:, [0, 0+6]]
NeuN_TDP_R_CT2 = NeuN_TDP_R[:, [1, 1+6]]
NeuN_TDP_R_CT3d = NeuN_TDP_R[:, [2, 2+6]]
NeuN_TDP_R_CT3v = NeuN_TDP_R[:, [3, 3+6]]
NeuN_TDP_R_CT4 = NeuN_TDP_R[:, [4, 4+6]]
NeuN_TDP_R_CT5 = NeuN_TDP_R[:, [5, 5+6]]

# %% [markdown]
# ## Number of regions we are analyzing (N = 10)

# %%
#N = NeuN_HC_L.shape[1]
N=2

# %% [markdown]
# ## Calculate the W-Scores

# %%
# L
## CT1
NeuN_HC_w_L_CT1, NeuN_Tau_w_L_CT1, NeuN_TDP_w_L_CT1 = wScore.generateWScore(hcCov_L_CT1, tauCov_L_CT1, tdpCov_L_CT1, 
                                                                            N, 
                                                                            NeuN_HC_L_CT1, 
                                                                            NeuN_Tau_L_CT1,  
                                                                            NeuN_TDP_L_CT1)
## CT2
NeuN_HC_w_L_CT2, NeuN_Tau_w_L_CT2, NeuN_TDP_w_L_CT2 = wScore.generateWScore(hcCov_L_CT2, tauCov_L_CT2, tdpCov_L_CT2, 
                                                                            N, 
                                                                            NeuN_HC_L_CT2, 
                                                                            NeuN_Tau_L_CT2,  
                                                                            NeuN_TDP_L_CT2)
## CT3d
NeuN_HC_w_L_CT3d, NeuN_Tau_w_L_CT3d, NeuN_TDP_w_L_CT3d = wScore.generateWScore(hcCov_L_CT3d, tauCov_L_CT3d, tdpCov_L_CT3d, 
                                                                            N, 
                                                                            NeuN_HC_L_CT3d, 
                                                                            NeuN_Tau_L_CT3d,  
                                                                            NeuN_TDP_L_CT3d)

## CT3v
NeuN_HC_w_L_CT3v, NeuN_Tau_w_L_CT3v, NeuN_TDP_w_L_CT3v = wScore.generateWScore(hcCov_L_CT3v, tauCov_L_CT3v, tdpCov_L_CT3v, 
                                                                            N, 
                                                                            NeuN_HC_L_CT3v, 
                                                                            NeuN_Tau_L_CT3v,  
                                                                            NeuN_TDP_L_CT3v)
## CT4
NeuN_HC_w_L_CT4, NeuN_Tau_w_L_CT4, NeuN_TDP_w_L_CT4 = wScore.generateWScore(hcCov_L_CT4, tauCov_L_CT4, tdpCov_L_CT4, 
                                                                            N, 
                                                                            NeuN_HC_L_CT4, 
                                                                            NeuN_Tau_L_CT4,  
                                                                            NeuN_TDP_L_CT4)
## CT5
NeuN_HC_w_L_CT5, NeuN_Tau_w_L_CT5, NeuN_TDP_w_L_CT5 = wScore.generateWScore(hcCov_L_CT5, tauCov_L_CT5, tdpCov_L_CT5, 
                                                                            N, 
                                                                            NeuN_HC_L_CT5, 
                                                                            NeuN_Tau_L_CT5,  
                                                                            NeuN_TDP_L_CT5)

# %%
NeuN_HC_w_L = np.zeros(NeuN_HC_L.shape)
NeuN_Tau_w_L = np.zeros(NeuN_Tau_L.shape)
NeuN_TDP_w_L = np.zeros(NeuN_TDP_L.shape)

for i in range(6):
    if i == 0:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT1
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT1
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT1
        
    elif i == 1:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT2
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT2
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT2
        
    elif i == 2:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT3d
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT3d
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT3d

    elif i == 3:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT3v
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT3v
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT3v
        
    elif i == 4:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT4
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT4
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT4
        
    else:
        NeuN_HC_w_L[:, [i, i+6]] = NeuN_HC_w_L_CT5
        NeuN_Tau_w_L[:, [i, i+6]] = NeuN_Tau_w_L_CT5
        NeuN_TDP_w_L[:, [i, i+6]] = NeuN_TDP_w_L_CT5

# %%
# R
## CT1
NeuN_HC_w_R_CT1, NeuN_Tau_w_R_CT1, NeuN_TDP_w_R_CT1 = wScore.generateWScore(hcCov_R_CT1, tauCov_R_CT1, tdpCov_R_CT1, 
                                                                            N, 
                                                                            NeuN_HC_R_CT1, 
                                                                            NeuN_Tau_R_CT1,  
                                                                            NeuN_TDP_R_CT1)
## CT2
NeuN_HC_w_R_CT2, NeuN_Tau_w_R_CT2, NeuN_TDP_w_R_CT2 = wScore.generateWScore(hcCov_R_CT2, tauCov_R_CT2, tdpCov_R_CT2, 
                                                                            N, 
                                                                            NeuN_HC_R_CT2, 
                                                                            NeuN_Tau_R_CT2,  
                                                                            NeuN_TDP_R_CT2)
## CT3d
NeuN_HC_w_R_CT3d, NeuN_Tau_w_R_CT3d, NeuN_TDP_w_R_CT3d = wScore.generateWScore(hcCov_R_CT3d, tauCov_R_CT3d, tdpCov_R_CT3d, 
                                                                            N, 
                                                                            NeuN_HC_R_CT3d, 
                                                                            NeuN_Tau_R_CT3d,  
                                                                            NeuN_TDP_R_CT3d)

## CT3v
NeuN_HC_w_R_CT3v, NeuN_Tau_w_R_CT3v, NeuN_TDP_w_R_CT3v = wScore.generateWScore(hcCov_R_CT3v, tauCov_R_CT3v, tdpCov_R_CT3v, 
                                                                            N, 
                                                                            NeuN_HC_R_CT3v, 
                                                                            NeuN_Tau_R_CT3v,  
                                                                            NeuN_TDP_R_CT3v)
## CT4
NeuN_HC_w_R_CT4, NeuN_Tau_w_R_CT4, NeuN_TDP_w_R_CT4 = wScore.generateWScore(hcCov_R_CT4, tauCov_R_CT4, tdpCov_R_CT4, 
                                                                            N, 
                                                                            NeuN_HC_R_CT4, 
                                                                            NeuN_Tau_R_CT4,  
                                                                            NeuN_TDP_R_CT4)
## CT5
NeuN_HC_w_R_CT5, NeuN_Tau_w_R_CT5, NeuN_TDP_w_R_CT5 = wScore.generateWScore(hcCov_R_CT5, tauCov_R_CT5, tdpCov_R_CT5, 
                                                                            N, 
                                                                            NeuN_HC_R_CT5, 
                                                                            NeuN_Tau_R_CT5,  
                                                                            NeuN_TDP_R_CT5)

# %%
NeuN_HC_w_R = np.zeros(NeuN_HC_R.shape)
NeuN_Tau_w_R = np.zeros(NeuN_Tau_R.shape)
NeuN_TDP_w_R = np.zeros(NeuN_TDP_R.shape)

for i in range(6):
    if i == 0:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT1
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT1
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT1
        
    elif i == 1:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT2
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT2
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT2
        
    elif i == 2:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT3d
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT3d
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT3d

    elif i == 3:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT3v
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT3v
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT3v
        
    elif i == 4:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT4
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT4
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT4
        
    else:
        NeuN_HC_w_R[:, [i, i+6]] = NeuN_HC_w_R_CT5
        NeuN_Tau_w_R[:, [i, i+6]] = NeuN_Tau_w_R_CT5
        NeuN_TDP_w_R[:, [i, i+6]] = NeuN_TDP_w_R_CT5

# %% [markdown]
# # Show Data Distribution Before and After W-Score

# %% [markdown]
# ## Before

# %%
bp.drawthicknessboxplot(NeuN_HC_L, NeuN_Tau_L, NeuN_TDP_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(NeuN).png")

# %%
bp.drawthicknessboxplot(NeuN_HC_R, NeuN_Tau_R, NeuN_TDP_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(NeuN).png")

# %% [markdown]
# ## After

# %%
NeuN_HC_w_L
# Out:
# array([[-1.08239769, -0.39297166, -1.07094041,  0.28484016, -0.33496867,
#                 nan, -0.50316972, -0.47807769, -0.31629409, -1.31493965,
#         -0.54540832,         nan],
#        [        nan,         nan,         nan, -0.56941636, -0.31113858,
#          0.25506695,         nan,         nan,         nan,  1.61022269,
#          0.61771737,  0.61943916],
#        [        nan, -0.52665859, -0.03645673, -0.42045511,  0.27959746,
#                 nan,         nan, -1.21815529, -0.90637183, -0.83341508,
#          0.22843552,         nan],
#        [-0.14030212,  0.51258052,  0.5625867 ,         nan, -0.64737449,
#                 nan, -1.12029038,  0.28971324,  0.04046683,         nan,
#         -1.07602471,         nan],
#        [-1.69466561, -1.59420553,         nan,         nan,         nan,
#                 nan,  1.14179832, -0.01506143,         nan,         nan,
#                 nan,         nan],
# ...

# %%
bp.drawthicknessboxplot(NeuN_HC_w_L, NeuN_Tau_w_L, NeuN_TDP_w_L, ['HC_L', 'TAU_L', 'TDP_L'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(NeuN)_WScore.png")

# %%
bp.drawthicknessboxplot(NeuN_HC_w_R, NeuN_Tau_w_R, NeuN_TDP_w_R, ['HC_R', 'TAU_R', 'TDP_R'], 'Mean', 
                        "Mean Distribution for 10 regions", layer_Fig, 
                        "Layer_Distribution(NeuN)_WScore.png")

# %% [markdown]
# # Saving

# %%
# NeuN_HC_w_L
with open(os.path.join(layer_dataDir, 'NeuN_HC_w_L.pkl'), 'wb') as f:
    pickle.dump(NeuN_HC_w_L, f)
f.close()

# NeuN_Tau_w_L
with open(os.path.join(layer_dataDir, 'NeuN_Tau_w_L.pkl'), 'wb') as f:
    pickle.dump(NeuN_Tau_w_L, f)
f.close()

# NeuN_TDP_w_L
with open(os.path.join(layer_dataDir, 'NeuN_TDP_w_L.pkl'), 'wb') as f:
    pickle.dump(NeuN_TDP_w_L, f)
f.close()

# %%
# NeuN_HC_w_R
with open(os.path.join(layer_dataDir, 'NeuN_HC_w_R.pkl'), 'wb') as f:
    pickle.dump(NeuN_HC_w_R, f)
f.close()

# NeuN_Tau_w_R
with open(os.path.join(layer_dataDir, 'NeuN_Tau_w_R.pkl'), 'wb') as f:
    pickle.dump(NeuN_Tau_w_R, f)
f.close()

# NeuN_TDP_w_R
with open(os.path.join(layer_dataDir, 'NeuN_TDP_w_R.pkl'), 'wb') as f:
    pickle.dump(NeuN_TDP_w_R, f)
f.close()

# %%
data = NeuN_HC_L

# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (BEFORE W-Score):")
print(nan_count_per_column)

data = NeuN_HC_w_L
# Count NaN values in each column
nan_count_per_column = np.sum(np.isnan(data), axis=0)

print("Number of NaN values in each column (AFTER W-Score):")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column (BEFORE W-Score):
# [5 2 8 8 4 6 5 2 8 8 4 6]
# Number of NaN values in each column (AFTER W-Score):
# [5 2 8 8 4 6 5 2 8 8 4 6]

# %%
pd.DataFrame(NeuN_HC_L)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.056535  0.055624  0.053127  0.072684  0.072643       NaN  0.054666
# 1        NaN       NaN       NaN  0.055136  0.068949  0.086550       NaN
# 2        NaN  0.052697  0.065789  0.052277  0.074254       NaN       NaN
# 3   0.064410  0.064483  0.067214       NaN  0.068783       NaN  0.049476
# 4   0.038707  0.046780       NaN       NaN       NaN       NaN  0.062746
# 5   0.042690  0.063951  0.067204       NaN  0.092396       NaN  0.043290
# 6   0.041369  0.049805       NaN  0.057438  0.058810  0.042804  0.041670
# 7   0.074447  0.060526  0.070178       NaN       NaN  0.084089  0.072143
# 8   0.046869  0.049450  0.055996  0.076026  0.073866  0.081546  0.047572
# 9   0.046147  0.056446       NaN       NaN       NaN  0.063619  0.061432
# 10  0.070575  0.065381       NaN  0.096420  0.096198  0.078146  0.035939
# 11       NaN       NaN       NaN  0.059746  0.061437  0.052206       NaN
# ...

# %%
pd.DataFrame(NeuN_HC_w_L)
# Out:
#           0         1         2         3         4         5         6   \
# 0  -1.082398 -0.392972 -1.070940  0.284840 -0.334969       NaN -0.503170
# 1        NaN       NaN       NaN -0.569416 -0.311139  0.255067       NaN
# 2        NaN -0.526659 -0.036457 -0.420455  0.279597       NaN       NaN
# 3  -0.140302  0.512581  0.562587       NaN -0.647374       NaN -1.120290
# 4  -1.694666 -1.594206       NaN       NaN       NaN       NaN  1.141798
# 5  -0.369032  0.464707 -0.389345       NaN  1.496544       NaN -0.371703
# 6  -0.372728 -0.926257       NaN  0.263381 -1.060224 -1.981133 -0.418835
# 7   1.446437  0.246084  0.544810       NaN       NaN  0.055419  1.939092
# 8  -0.100661 -1.100514 -1.472133  1.005207 -0.245232  1.188917 -0.080717
# 9  -0.881688 -0.633724       NaN       NaN       NaN -0.305741  0.912704
# 10  2.117973  0.307329       NaN  1.281893  0.916538  0.889966 -2.046261
# 11       NaN       NaN       NaN -1.434951 -1.573980 -1.230974       NaN
# ...
