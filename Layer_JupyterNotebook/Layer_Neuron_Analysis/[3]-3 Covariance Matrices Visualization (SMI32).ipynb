# %% [markdown]
# # Import

# %%
import sys
import os
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Covariance Matrices

# %%
# cov_SMI32_dict
with open(os.path.join(layer_CalData, 'cov_SMI32_dict.pkl'), 'rb') as f:
    cov_SMI32_dict = pickle.load(f)
f.close()

# %%
# cov_SMI32_dict_w
with open(os.path.join(layer_CalData, 'cov_SMI32_dict_w.pkl'), 'rb') as f:
    cov_SMI32_dict_w = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Layer Neuron Labels (SMI32)

# %%
# SMI32_Labels
with open(os.path.join(layer_dataDir, 'SMI32_Labels.pkl'), 'rb') as f:
    SMI32_Labels = pickle.load(f)
f.close()

# %% [markdown]
# # Visualize and save Covariance Matrices (SMI32)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %% [markdown]
#  Show the values even < 0.1

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_gt_TDP'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_gt_TAU'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (SMI32) W Score

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TAU_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TAU_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TDP_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TDP_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TAU_gt_TDP'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w['TDP_gt_TAU'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)
