# %% [markdown]
# # Import

# %%
import sys
import os
import pickle

# %% [markdown]
# ## Helper Functions

# %%
# %store -r analysis_hf
sys.path.insert(0, analysis_hf)
import visualization as viz

# %% [markdown]
# # Set Directory Paths

# %%
# Directory path to load formatted Layer Data
# %store -r layer_dataDir

# Directory path to save Calcualted Analysis Data
# %store -r layer_CalData

# Directory path to save Figures
# %store -r layer_Fig

# %% [markdown]
# # Loading

# %% [markdown]
# ## Loading Covariance Matrices

# %%
# cov_SMI32_dict
with open(os.path.join(layer_CalData, 'cov_SMI32_dict.pkl'), 'rb') as f:
    cov_SMI32_dict = pickle.load(f)
f.close()

# %%
# cov_SMI32_dict_w_agesex
with open(os.path.join(layer_CalData, 'cov_SMI32_dict_w_agesex.pkl'), 'rb') as f:
    cov_SMI32_dict_w_agesex = pickle.load(f)
f.close()

# cov_SMI32_dict_w_agesexNeuNADNC
with open(os.path.join(layer_CalData, 'cov_SMI32_dict_w_agesexNeuNADNC.pkl'), 'rb') as f:
    cov_SMI32_dict_w_agesexNeuNADNC = pickle.load(f)
f.close()

# %% [markdown]
# ## Loading Layer Neuron Labels (SMI32)

# %%
# SMI32_Labels
with open(os.path.join(layer_dataDir, 'SMI32_Labels.pkl'), 'rb') as f:
    SMI32_Labels = pickle.load(f)
f.close()

# %%
SMI32_Labels
# Out:
# ['ln_L23_1',
#  'ln_L23_2',
#  'ln_L23_3d',
#  'ln_L23_3v',
#  'ln_L23_4',
#  'ln_L23_5',
#  'ln_L56_1',
#  'ln_L56_2',
#  'ln_L56_3d',
#  'ln_L56_3v',
#  'ln_L56_4',
#  'ln_L56_5']

# %%
SMI32_Labels = ['L23_1(Cingulate)', 'L23_2(Cingulate)', 'L23_3d(Paracingulate)', 'L23_3v(Paracingulate)', 'L23_4(Rectus)', 'L23_5(Middle Frontal)', 
               'L56_1(Cingulate)', 'L56_2(Cingulate)', 'L56_3d(Paracingulate)', 'L56_3v(Paracingulate)', 'L56_4(Rectus)', 'L56_5(Middle Frontal)']

# %% [markdown]
# # Visualize and save Covariance Matrices (SMI32)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %% [markdown]
#  Show the values even < 0.1

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > HC (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict['TAU_gt_TDP'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > TDP (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict['TDP_gt_TAU'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > Tau (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Divide into Long, Short Paths

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC (covMat) - Long(Canonical)', subpath = 'canonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC (covMat) - Long(Non-Canonical)', subpath = 'noncanonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC (covMat) - Short', subpath = 'short', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau (covMat) - Long(Canonical)', subpath = 'canonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau (covMat) - Long(Non-Canonical)', subpath = 'noncanonical', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau (covMat) - Short', subpath = 'short', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP (covMat) - Long(Canonical)', subpath='canonical',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP (covMat) - Long(Non-Canonical)', subpath='noncanonical',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %%
viz.drawCovMatrixSubpath(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP (covMat) - Short', subpath='short',  outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Stratification

# %%
maxval = 0.0
minval = -0.2
viz.drawCovMatrixStrat(cov_SMI32_dict['TDP'], SMI32_Labels, SMI32_Labels, f'SMI32_TDP (covMat) {maxval} ~ {minval}', minval=minval, maxval=maxval, outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (SMI32) W Score (Age, sex)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TAU_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TAU_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TDP_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TDP_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TAU_gt_TDP'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesex['TDP_gt_TAU'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# # Visualize and save Covariance Matrices (SMI32) W Score (Age, sex, NeuN, ADNC)

# %% [markdown]
# ## HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['HC'], SMI32_Labels, SMI32_Labels, 'SMI32_HC_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TAU'], SMI32_Labels, SMI32_Labels, 'SMI32_Tau_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TDP'], SMI32_Labels, SMI32_Labels, 'SMI32_TDP_w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TAU_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TAU_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## HC > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TDP_lt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 HC > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > HC

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TDP_gt_HC'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > HC w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## Tau > TDP

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TAU_gt_TDP'], SMI32_Labels, SMI32_Labels, 'SMI32 Tau > TDP w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)

# %% [markdown]
# ## TDP > Tau

# %%
viz.drawCovMatrix(cov_SMI32_dict_w_agesexNeuNADNC['TDP_gt_TAU'], SMI32_Labels, SMI32_Labels, 'SMI32 TDP > Tau w (covMat)', outputDir = layer_Fig,
                  annot_fontsize = 6, tick_fontsize = 6, annot_bool = True, save=True)
