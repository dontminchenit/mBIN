# %%
import os

# %% [markdown]
# # Directory Path to mBIN gitrepo

# %%
# gitRepoDir = "/Users/hyroh/Desktop/FTD_Research/mBIN"
gitRepoDir = "/Users/hyung/Research23_Network_Analysis/mBIN"
# %store gitRepoDir
# Out:
# Stored 'gitRepoDir' (str)

# %% [markdown]
# # Directory Path to Data Folder

# %%
# Location of the raw data folder
# dataDir='/Users/hyroh/Desktop/FTD_Research/Layer_Data'
dataDir = '/Users/hyung/Research23_Network_Analysis/Layer_Data'
# %store dataDir
# Out:
# Stored 'dataDir' (str)

# %% [markdown]
# # Directory Path to Helper Functions

# %% [markdown]
# # Layer Neuron Data

# %% [markdown]
# ## Directory Path to load formatted Layer Neuron Data

# %%
# Directory path to load formatted Layer Neuron Data
layer_dataDir= os.path.join(gitRepoDir, 'Layer_JupyterNotebook/Data/Layer_Neuron_Data')
# %store layer_dataDir
# Out:
# Stored 'layer_dataDir' (str)

# %% [markdown]
# ## Directory Path to save Layer Neuron Analysis Calculations

# %%
# Directory path to save Calcualted Analysis Data
layer_CalData = os.path.join(gitRepoDir, 'Layer_JupyterNotebook/Layer_Neuron_Analysis/Calculated_Data')
# %store layer_CalData
# Out:
# Stored 'layer_CalData' (str)

# %% [markdown]
# ## Directory path to save Figures

# %%
layer_Fig = os.path.join(gitRepoDir, 'Layer_JupyterNotebook/Layer_Neuron_Analysis/Figures')
# %store layer_Fig
# Out:
# Stored 'layer_Fig' (str)
